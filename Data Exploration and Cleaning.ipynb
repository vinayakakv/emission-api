# %% [markdown]
# # Data Exploration and Cleaning
#
# In this notebook, we load and understand the data, and clean and export it to JSON format, to be used with the APIs.
#
# As a pre-requisite,
# - Install `jupyter`
# - Install `pandas` via `pip` (`numpy` will be installed automatically as a dependency)
# - Make sure that the `data` folder contains the dataset
#
# ## Data Loading

# %%
import pandas as pd

# %%
import numpy as np

# %%
import json

# %%
data = pd.read_csv("data/greenhouse_gas_inventory_data_data.csv")

# %%
data
# Out:
#                country_or_area  year          value  \
# 0                    Australia  2014  393126.946994
# 1                    Australia  2013  396913.936530
# 2                    Australia  2012  406462.847704
# 3                    Australia  2011  403705.528314
# 4                    Australia  2010  406200.993184
# ...                        ...   ...            ...
# 8401  United States of America  1994     593.222570
# 8402  United States of America  1993     586.939752
# 8403  United States of America  1992     574.414624
# 8404  United States of America  1991     566.900968
# 8405  United States of America  1990     293.205663
#
#                                                category
# 0     carbon_dioxide_co2_emissions_without_land_use_...
# 1     carbon_dioxide_co2_emissions_without_land_use_...
# 2     carbon_dioxide_co2_emissions_without_land_use_...
# 3     carbon_dioxide_co2_emissions_without_land_use_...
# 4     carbon_dioxide_co2_emissions_without_land_use_...
# ...                                                 ...
# 8401  unspecified_mix_of_hydrofluorocarbons_hfcs_and...
# 8402  unspecified_mix_of_hydrofluorocarbons_hfcs_and...
# 8403  unspecified_mix_of_hydrofluorocarbons_hfcs_and...
# 8404  unspecified_mix_of_hydrofluorocarbons_hfcs_and...
# 8405  unspecified_mix_of_hydrofluorocarbons_hfcs_and...
#
# [8406 rows x 4 columns]

# %% [markdown]
# We see that the dataset contains the country name, along with emission values belonging to several categories.
#
# Let's dig deep into see which categories are present
#
# ## Unique Categories

# %%
data['category'].unique()
# Out:
# array(['carbon_dioxide_co2_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent',
#        'greenhouse_gas_ghgs_emissions_including_indirect_co2_without_lulucf_in_kilotonne_co2_equivalent',
#        'greenhouse_gas_ghgs_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent',
#        'hydrofluorocarbons_hfcs_emissions_in_kilotonne_co2_equivalent',
#        'methane_ch4_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent',
#        'nitrogen_trifluoride_nf3_emissions_in_kilotonne_co2_equivalent',
#        'nitrous_oxide_n2o_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent',
#        'perfluorocarbons_pfcs_emissions_in_kilotonne_co2_equivalent',
#        'sulphur_hexafluoride_sf6_emissions_in_kilotonne_co2_equivalent',
#        'unspecified_mix_of_hydrofluorocarbons_hfcs_and_perfluorocarbons_pfcs_emissions_in_kilotonne_co2_equivalent'],
#       dtype=object)

# %% [markdown]
# We see some of the categories listing chemicals or chemical groups, while others are generals. We shall pick following chemicals and chemical groups for this exercise. We shall also rename them afterwards.
#
# - CO<sub>2</sub>
# - HFCs
# - CH<sub>4</sub>
# - NF<sub>3</sub>
# - N<sub>2</sub>O
# - PFCs
# - SF<sub>6</sub>
#
# Since all of the of the units are in _kilotonnes of CO2 equivalent_, we can use them directly, without any modification.
#
# ## Picking and Renaming the Categories
#
# We use the `new_data` variable for the cleaned dataset. It will be re-assigned several times in the future usages.

# %%
new_data = data.loc[data['category'].isin([
    'carbon_dioxide_co2_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent',
    'hydrofluorocarbons_hfcs_emissions_in_kilotonne_co2_equivalent',
    'methane_ch4_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent',
    'nitrogen_trifluoride_nf3_emissions_in_kilotonne_co2_equivalent',
    'nitrous_oxide_n2o_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent',
    'perfluorocarbons_pfcs_emissions_in_kilotonne_co2_equivalent',
    'sulphur_hexafluoride_sf6_emissions_in_kilotonne_co2_equivalent',
])]
new_data
# Out:
#                country_or_area  year          value  \
# 0                    Australia  2014  393126.946994
# 1                    Australia  2013  396913.936530
# 2                    Australia  2012  406462.847704
# 3                    Australia  2011  403705.528314
# 4                    Australia  2010  406200.993184
# ...                        ...   ...            ...
# 8326  United States of America  1994   28004.247351
# 8327  United States of America  1993   29432.652199
# 8328  United States of America  1992   29949.821295
# 8329  United States of America  1991   29764.563408
# 8330  United States of America  1990   31080.406159
#
#                                                category
# 0     carbon_dioxide_co2_emissions_without_land_use_...
# 1     carbon_dioxide_co2_emissions_without_land_use_...
# 2     carbon_dioxide_co2_emissions_without_land_use_...
# 3     carbon_dioxide_co2_emissions_without_land_use_...
# 4     carbon_dioxide_co2_emissions_without_land_use_...
# ...                                                 ...
# 8326  sulphur_hexafluoride_sf6_emissions_in_kilotonn...
# 8327  sulphur_hexafluoride_sf6_emissions_in_kilotonn...
# 8328  sulphur_hexafluoride_sf6_emissions_in_kilotonn...
# 8329  sulphur_hexafluoride_sf6_emissions_in_kilotonn...
# 8330  sulphur_hexafluoride_sf6_emissions_in_kilotonn...
#
# [6308 rows x 4 columns]

# %%
new_data = new_data.replace({
    'category': {
        'carbon_dioxide_co2_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent': 'CO2',
        'hydrofluorocarbons_hfcs_emissions_in_kilotonne_co2_equivalent': 'HFCs',
        'methane_ch4_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent': 'CH4',
        'nitrogen_trifluoride_nf3_emissions_in_kilotonne_co2_equivalent': 'NF3',
        'nitrous_oxide_n2o_emissions_without_land_use_land_use_change_and_forestry_lulucf_in_kilotonne_co2_equivalent': 'N2O',
        'perfluorocarbons_pfcs_emissions_in_kilotonne_co2_equivalent': 'PFCs',
        'sulphur_hexafluoride_sf6_emissions_in_kilotonne_co2_equivalent': 'SF6',
    }
})
new_data
# Out:
#                country_or_area  year          value category
# 0                    Australia  2014  393126.946994      CO2
# 1                    Australia  2013  396913.936530      CO2
# 2                    Australia  2012  406462.847704      CO2
# 3                    Australia  2011  403705.528314      CO2
# 4                    Australia  2010  406200.993184      CO2
# ...                        ...   ...            ...      ...
# 8326  United States of America  1994   28004.247351      SF6
# 8327  United States of America  1993   29432.652199      SF6
# 8328  United States of America  1992   29949.821295      SF6
# 8329  United States of America  1991   29764.563408      SF6
# 8330  United States of America  1990   31080.406159      SF6
#
# [6308 rows x 4 columns]

# %%
new_data['category'].unique()
# Out:
# array(['CO2', 'HFCs', 'CH4', 'NF3', 'N2O', 'PFCs', 'SF6'], dtype=object)

# %% [markdown]
# Good! Now that the catgories are looking clean, we shall look at the countries.

# %%
new_data['country_or_area'].unique()
# Out:
# array(['Australia', 'Austria', 'Belarus', 'Belgium', 'Bulgaria', 'Canada',
#        'Croatia', 'Cyprus', 'Czech Republic', 'Denmark', 'Estonia',
#        'European Union', 'Finland', 'France', 'Germany', 'Greece',
#        'Hungary', 'Iceland', 'Ireland', 'Italy', 'Japan', 'Latvia',
#        'Liechtenstein', 'Lithuania', 'Luxembourg', 'Malta', 'Monaco',
#        'Netherlands', 'New Zealand', 'Norway', 'Poland', 'Portugal',
#        'Romania', 'Russian Federation', 'Slovakia', 'Slovenia', 'Spain',
#        'Sweden', 'Switzerland', 'Turkey', 'Ukraine', 'United Kingdom',
#        'United States of America'], dtype=object)

# %% [markdown]
# Here, we observe some things:
# - Countries are represented by the name
# - Eurpoean Union data is present, along with its member countries' (See Gernmany, Italy, Netherlands etc.)
#
# ## Cleaning the countries
# To make the data consistent,
# - Remove EU from the data
# - Convert country names to ISO A3 3-letter country code format. (We do this, as the [GeoJSON of country borders we would be using in the frontend](https://datahub.io/core/geo-countries) uses ISO A3 country codes)

# %%
new_data = new_data.loc[data['country_or_area']!= "European Union"]
new_data
# Out:
#                country_or_area  year          value category
# 0                    Australia  2014  393126.946994      CO2
# 1                    Australia  2013  396913.936530      CO2
# 2                    Australia  2012  406462.847704      CO2
# 3                    Australia  2011  403705.528314      CO2
# 4                    Australia  2010  406200.993184      CO2
# ...                        ...   ...            ...      ...
# 8326  United States of America  1994   28004.247351      SF6
# 8327  United States of America  1993   29432.652199      SF6
# 8328  United States of America  1992   29949.821295      SF6
# 8329  United States of America  1991   29764.563408      SF6
# 8330  United States of America  1990   31080.406159      SF6
#
# [6133 rows x 4 columns]

# %% [markdown]
# As a verification, we look at the countries again

# %%
new_data['country_or_area'].unique()
# Out:
# array(['Australia', 'Austria', 'Belarus', 'Belgium', 'Bulgaria', 'Canada',
#        'Croatia', 'Cyprus', 'Czech Republic', 'Denmark', 'Estonia',
#        'Finland', 'France', 'Germany', 'Greece', 'Hungary', 'Iceland',
#        'Ireland', 'Italy', 'Japan', 'Latvia', 'Liechtenstein',
#        'Lithuania', 'Luxembourg', 'Malta', 'Monaco', 'Netherlands',
#        'New Zealand', 'Norway', 'Poland', 'Portugal', 'Romania',
#        'Russian Federation', 'Slovakia', 'Slovenia', 'Spain', 'Sweden',
#        'Switzerland', 'Turkey', 'Ukraine', 'United Kingdom',
#        'United States of America'], dtype=object)

# %% [markdown]
# Now that the the list contain all the countries, we shall convert them into A3 codes using [this list](https://www.rocketroute.com/iso-country-code-list). We may not need to retain the name, as the GeoJSON already contains it.

# %%
country_map = {
       'Australia': 'AUS', 'Austria': 'AUT', 'Belarus': 'BLR', 'Belgium': 'BEL', 'Bulgaria': 'BGR', 'Canada': 'CAN',
       'Croatia': 'HRV', 'Cyprus': 'CYP', 'Czech Republic': 'CZE', 'Denmark': 'DNK', 'Estonia': 'EST',
       'Finland': 'FIN', 'France': 'FRA', 'Germany': 'DEU', 'Greece': 'GRC',
       'Hungary': 'HUN', 'Iceland': 'ISL', 'Ireland': 'IRL', 'Italy': 'ITA', 'Japan': 'JPN', 'Latvia': 'LVA',
       'Liechtenstein': 'LIE', 'Lithuania': 'LTU', 'Luxembourg': 'LUX', 'Malta': 'MLT', 'Monaco': 'MCO',
       'Netherlands': 'NLD', 'New Zealand': 'NZL', 'Norway': 'NOR', 'Poland': 'POL', 'Portugal': 'PRT',
       'Romania': 'ROU', 'Russian Federation': 'RUS', 'Slovakia': 'SVK', 'Slovenia':'SVN', 'Spain': 'ESP',
       'Sweden': 'SWE', 'Switzerland': 'CHE', 'Turkey': 'TUR', 'Ukraine': 'UKR', 'United Kingdom': 'GBR',
       'United States of America': 'USA'
}

# %%
new_data['country_code'] = new_data['country_or_area'].map(country_map)
new_data
# Out:
# /tmp/ipykernel_12930/501431545.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data['country_code'] = new_data['country_or_area'].map(country_map)
#                country_or_area  year          value category country_code
# 0                    Australia  2014  393126.946994      CO2          AUS
# 1                    Australia  2013  396913.936530      CO2          AUS
# 2                    Australia  2012  406462.847704      CO2          AUS
# 3                    Australia  2011  403705.528314      CO2          AUS
# 4                    Australia  2010  406200.993184      CO2          AUS
# ...                        ...   ...            ...      ...          ...
# 8326  United States of America  1994   28004.247351      SF6          USA
# 8327  United States of America  1993   29432.652199      SF6          USA
# 8328  United States of America  1992   29949.821295      SF6          USA
# 8329  United States of America  1991   29764.563408      SF6          USA
# 8330  United States of America  1990   31080.406159      SF6          USA
#
# [6133 rows x 5 columns]

# %%
new_data['country_code'].unique()
# Out:
# array(['AUS', 'AUT', 'BLR', 'BEL', 'BGR', 'CAN', 'HRV', 'CYP', 'CZE',
#        'DNK', 'EST', 'FIN', 'FRA', 'DEU', 'GRC', 'HUN', 'ISL', 'IRL',
#        'ITA', 'JPN', 'LVA', 'LIE', 'LTU', 'LUX', 'MLT', 'MCO', 'NLD',
#        'NZL', 'NOR', 'POL', 'PRT', 'ROU', 'RUS', 'SVK', 'SVN', 'ESP',
#        'SWE', 'CHE', 'TUR', 'UKR', 'GBR', 'USA'], dtype=object)

# %% [markdown]
# Now, we shall look at the `value` column, which is the emission value in Kilotonnes of CO<sub>2</sub> equivalent.
#
# The value `29764.563408` kilotonne has 6 significant digits after decimal point, meaning it is precise upto a kg. We may not need that precision, so we keep 2 significant difits after decimal point, meaning, it is precise upto 10 tons.
#
# ## Rounding the emission `value`

# %%
new_data['value'] = np.round(new_data['value'],2)
new_data
# Out:
# /tmp/ipykernel_12930/3892214510.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data['value'] = np.round(new_data['value'],2)
#                country_or_area  year      value category country_code
# 0                    Australia  2014  393126.95      CO2          AUS
# 1                    Australia  2013  396913.94      CO2          AUS
# 2                    Australia  2012  406462.85      CO2          AUS
# 3                    Australia  2011  403705.53      CO2          AUS
# 4                    Australia  2010  406200.99      CO2          AUS
# ...                        ...   ...        ...      ...          ...
# 8326  United States of America  1994   28004.25      SF6          USA
# 8327  United States of America  1993   29432.65      SF6          USA
# 8328  United States of America  1992   29949.82      SF6          USA
# 8329  United States of America  1991   29764.56      SF6          USA
# 8330  United States of America  1990   31080.41      SF6          USA
#
# [6133 rows x 5 columns]

# %% [markdown]
# Now that the data is looking good, we shall export it to a json, which the `nodejs` program will use to initialize the database.
#
# ## Database Export
#
# Before that, we have to think about the schema a little bit. Since the goal of the project is to provide 2 APIs
# - `GET /countries`
# - `GET /countries/{id}?query` (I have taken the freedom to change `/country/{id}` to `countries/{id}` as they refer to the same resource at different levels)
#
# We shall provide two tables
# 1. `countries` -- `country_id` as the sole-column
# 2. `emissions` -- `country_id` and `year` as primary key, `emission_values: {[chemical]: number}` as a JSON value (`sqlite` does not support them, so `string` and `JSON.parse` in the code).
#
# We choose JSON for emissions values because we may add some extra key in the future, making it easy to extend the data, without modifying the database
#
# We will write these models as a part of NodeJS source code, and create appropriate views of them to support the use-case.

# %%
countris = [{'id': y, 'name': x} for x,y in country_map.items()]
countris[:10]
# Out:
# [{'id': 'AUS', 'name': 'Australia'},
#  {'id': 'AUT', 'name': 'Austria'},
#  {'id': 'BLR', 'name': 'Belarus'},
#  {'id': 'BEL', 'name': 'Belgium'},
#  {'id': 'BGR', 'name': 'Bulgaria'},
#  {'id': 'CAN', 'name': 'Canada'},
#  {'id': 'HRV', 'name': 'Croatia'},
#  {'id': 'CYP', 'name': 'Cyprus'},
#  {'id': 'CZE', 'name': 'Czech Republic'},
#  {'id': 'DNK', 'name': 'Denmark'}]

# %%
new_data
# Out:
#                country_or_area  year      value category country_code
# 0                    Australia  2014  393126.95      CO2          AUS
# 1                    Australia  2013  396913.94      CO2          AUS
# 2                    Australia  2012  406462.85      CO2          AUS
# 3                    Australia  2011  403705.53      CO2          AUS
# 4                    Australia  2010  406200.99      CO2          AUS
# ...                        ...   ...        ...      ...          ...
# 8326  United States of America  1994   28004.25      SF6          USA
# 8327  United States of America  1993   29432.65      SF6          USA
# 8328  United States of America  1992   29949.82      SF6          USA
# 8329  United States of America  1991   29764.56      SF6          USA
# 8330  United States of America  1990   31080.41      SF6          USA
#
# [6133 rows x 5 columns]

# %%
new_data["emissions"] = new_data.apply(lambda row: [row["category"], row["value"]], axis=1)
new_data
# Out:
# /tmp/ipykernel_12930/2864945010.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data["emissions"] = new_data.apply(lambda row: [row["category"], row["value"]], axis=1)
#                country_or_area  year      value category country_code  \
# 0                    Australia  2014  393126.95      CO2          AUS
# 1                    Australia  2013  396913.94      CO2          AUS
# 2                    Australia  2012  406462.85      CO2          AUS
# 3                    Australia  2011  403705.53      CO2          AUS
# 4                    Australia  2010  406200.99      CO2          AUS
# ...                        ...   ...        ...      ...          ...
# 8326  United States of America  1994   28004.25      SF6          USA
# 8327  United States of America  1993   29432.65      SF6          USA
# 8328  United States of America  1992   29949.82      SF6          USA
# 8329  United States of America  1991   29764.56      SF6          USA
# 8330  United States of America  1990   31080.41      SF6          USA
#
#              emissions
# 0     [CO2, 393126.95]
# 1     [CO2, 396913.94]
# 2     [CO2, 406462.85]
# 3     [CO2, 403705.53]
# 4     [CO2, 406200.99]
# ...                ...
# 8326   [SF6, 28004.25]
# 8327   [SF6, 29432.65]
# 8328   [SF6, 29949.82]
# 8329   [SF6, 29764.56]
# 8330   [SF6, 31080.41]
#
# [6133 rows x 6 columns]

# %%
emissions_data = new_data.groupby(["country_code", "year"])["emissions"].apply(list)
emissions_data
# Out:
# country_code  year
# AUS           1990    [[CO2, 278265.9], [HFCs, 1424.68], [CH4, 11876...
#               1991    [[CO2, 279741.64], [HFCs, 1424.68], [CH4, 1177...
#               1992    [[CO2, 284766.09], [HFCs, 1333.18], [CH4, 1168...
#               1993    [[CO2, 289142.27], [HFCs, 1829.87], [CH4, 1138...
#               1994    [[CO2, 293830.71], [HFCs, 1027.34], [CH4, 1109...
#                                             ...
# USA           2010    [[CO2, 5688756.01], [HFCs, 141633.8], [CH4, 72...
#               2011    [[CO2, 5559507.66], [HFCs, 146080.6], [CH4, 71...
#               2012    [[CO2, 5349220.95], [HFCs, 147249.75], [CH4, 7...
#               2013    [[CO2, 5502550.71], [HFCs, 149922.39], [CH4, 7...
#               2014    [[CO2, 5556006.58], [HFCs, 157237.34], [CH4, 7...
# Name: emissions, Length: 1049, dtype: object

# %%
emissions = [ {"country_id": key[0], "year": key[1], "emissions": dict(value)} for key, value in emissions_data.to_dict().items()]
emissions
# Out:
# [{'country_id': 'AUS',
#   'year': 1990,
#   'emissions': {'CO2': 278265.9,
#    'HFCs': 1424.68,
#    'CH4': 118768.84,
#    'N2O': 15345.6,
#    'PFCs': 4607.01,
#    'SF6': 211.02}},
#  {'country_id': 'AUS',
#   'year': 1991,
#   'emissions': {'CO2': 279741.64,
#    'HFCs': 1424.68,
#    'CH4': 117744.64,
#    'N2O': 14923.41,
#    'PFCs': 4610.74,
#    'SF6': 228.94}},
#  {'country_id': 'AUS',
#   'year': 1992,
#   'emissions': {'CO2': 284766.09,
#    'HFCs': 1333.18,
#    'CH4': 116837.51,
#    'N2O': 15293.18,
#    'PFCs': 4603.28,
#    'SF6': 246.86}},
#  {'country_id': 'AUS',
#   'year': 1993,
#   'emissions': {'CO2': 289142.27,
#    'HFCs': 1829.87,
#    'CH4': 113837.51,
#    'N2O': 15374.99,
#    'PFCs': 3315.53,
#    'SF6': 264.76}},
#  {'country_id': 'AUS',
#   'year': 1994,
#   'emissions': {'CO2': 293830.71,
#    'HFCs': 1027.34,
#    'CH4': 110997.41,
#    'N2O': 15790.43,
#    'PFCs': 2164.43,
#    'SF6': 282.64}},
#  {'country_id': 'AUS',
#   'year': 1995,
#   'emissions': {'CO2': 305162.54,
#    'HFCs': 1004.03,
#    'CH4': 109900.74,
#    'N2O': 15578.2,
#    'PFCs': 1530.84,
#    'SF6': 302.31}},
#  {'country_id': 'AUS',
#   'year': 1996,
#   'emissions': {'CO2': 311914.82,
#    'HFCs': 414.17,
#    'CH4': 109185.34,
#    'N2O': 16609.59,
#    'PFCs': 1410.4,
#    'SF6': 269.65}},
#  {'country_id': 'AUS',
#   'year': 1997,
#   'emissions': {'CO2': 320439.12,
#    'HFCs': 705.23,
#    'CH4': 111898.85,
#    'N2O': 17201.89,
#    'PFCs': 1228.15,
#    'SF6': 248.48}},
#  {'country_id': 'AUS',
#   'year': 1998,
#   'emissions': {'CO2': 334328.14,
#    'HFCs': 998.29,
#    'CH4': 111427.93,
#    'N2O': 17743.91,
#    'PFCs': 1660.52,
#    'SF6': 223.32}},
#  {'country_id': 'AUS',
#   'year': 1999,
#   'emissions': {'CO2': 343713.91,
#    'HFCs': 1374.29,
#    'CH4': 107889.22,
#    'N2O': 17933.44,
#    'PFCs': 1139.06,
#    'SF6': 196.07}},
#  {'country_id': 'AUS',
#   'year': 2000,
#   'emissions': {'CO2': 349885.43,
#    'HFCs': 1613.2,
#    'CH4': 111520.31,
#    'N2O': 18949.17,
#    'PFCs': 1287.06,
#    'SF6': 190.65}},
#  {'country_id': 'AUS',
#   'year': 2001,
#   'emissions': {'CO2': 357653.33,
#    'HFCs': 2305.93,
#    'CH4': 110301.73,
#    'N2O': 19182.29,
#    'PFCs': 1801.88,
#    'SF6': 196.53}},
#  {'country_id': 'AUS',
#   'year': 2002,
#   'emissions': {'CO2': 361861.39,
#    'HFCs': 2926.73,
#    'CH4': 108309.14,
#    'N2O': 19712.73,
#    'PFCs': 1727.62,
#    'SF6': 202.48}},
#  {'country_id': 'AUS',
#   'year': 2003,
#   'emissions': {'CO2': 368345.98,
#    'HFCs': 3578.35,
#    'CH4': 102574.21,
#    'N2O': 18765.28,
#    'PFCs': 1683.98,
#    'SF6': 206.29}},
#  {'country_id': 'AUS',
#   'year': 2004,
#   'emissions': {'CO2': 381519.26,
#    'HFCs': 4266.92,
#    'CH4': 103839.21,
#    'N2O': 20163.24,
#    'PFCs': 1713.85,
#    'SF6': 207.76}},
#  {'country_id': 'AUS',
#   'year': 2005,
#   'emissions': {'CO2': 385581.13,
#    'HFCs': 5002.48,
#    'CH4': 105887.56,
#    'N2O': 20405.82,
#    'PFCs': 1791.7,
#    'SF6': 182.06}},
#  {'country_id': 'AUS',
#   'year': 2006,
#   'emissions': {'CO2': 391134.1,
#    'HFCs': 5456.52,
#    'CH4': 104842.39,
#    'N2O': 20224.61,
#    'PFCs': 687.06,
#    'SF6': 172.51}},
#  {'country_id': 'AUS',
#   'year': 2007,
#   'emissions': {'CO2': 398816.45,
#    'HFCs': 6143.73,
#    'CH4': 105174.67,
#    'N2O': 18963.12,
#    'PFCs': 582.68,
#    'SF6': 162.22}},
#  {'country_id': 'AUS',
#   'year': 2008,
#   'emissions': {'CO2': 404237.83,
#    'HFCs': 6832.23,
#    'CH4': 103119.55,
#    'N2O': 18908.28,
#    'PFCs': 444.52,
#    'SF6': 151.11}},
#  {'country_id': 'AUS',
#   'year': 2009,
#   'emissions': {'CO2': 408448.48,
#    'HFCs': 7468.94,
#    'CH4': 101886.83,
#    'N2O': 19607.63,
#    'PFCs': 358.55,
#    'SF6': 119.45}},
#  {'country_id': 'AUS',
#   'year': 2010,
#   'emissions': {'CO2': 406200.99,
#    'HFCs': 8166.07,
#    'CH4': 99447.73,
#    'N2O': 19698.3,
#    'PFCs': 283.32,
#    'SF6': 121.03}},
#  {'country_id': 'AUS',
#   'year': 2011,
#   'emissions': {'CO2': 403705.53,
#    'HFCs': 8837.85,
#    'CH4': 101085.54,
#    'N2O': 20034.58,
#    'PFCs': 301.3,
#    'SF6': 125.0}},
#  {'country_id': 'AUS',
#   'year': 2012,
#   'emissions': {'CO2': 406462.85,
#    'HFCs': 9353.07,
#    'CH4': 100796.84,
#    'N2O': 20342.38,
#    'PFCs': 294.88,
#    'SF6': 127.55}},
#  {'country_id': 'AUS',
#   'year': 2013,
#   'emissions': {'CO2': 396913.94,
#    'HFCs': 10034.13,
#    'CH4': 99857.2,
#    'N2O': 19756.45,
#    'PFCs': 192.0,
#    'SF6': 128.94}},
#  {'country_id': 'AUS',
#   'year': 2014,
#   'emissions': {'CO2': 393126.95,
#    'HFCs': 10787.35,
#    'CH4': 98076.11,
#    'N2O': 20084.54,
#    'PFCs': 192.54,
#    'SF6': 129.61}},
#  {'country_id': 'AUT',
#   'year': 1990,
#   'emissions': {'CO2': 62297.17,
#    'HFCs': 2.44,
#    'CH4': 10598.57,
#    'N2O': 4293.06,
#    'PFCs': 1182.79,
#    'SF6': 470.61}},
#  {'country_id': 'AUT',
#   'year': 1991,
#   'emissions': {'CO2': 65903.51,
#    'HFCs': 3.89,
#    'CH4': 10462.1,
#    'N2O': 4460.65,
#    'PFCs': 1192.62,
#    'SF6': 614.14}},
#  {'country_id': 'AUT',
#   'year': 1992,
#   'emissions': {'CO2': 60432.25,
#    'HFCs': 5.64,
#    'CH4': 10164.75,
#    'N2O': 4161.62,
#    'PFCs': 510.47,
#    'SF6': 656.27}},
#  {'country_id': 'AUT',
#   'year': 1993,
#   'emissions': {'CO2': 60790.76,
#    'HFCs': 235.26,
#    'CH4': 10073.83,
#    'N2O': 4080.85,
#    'PFCs': 63.52,
#    'SF6': 744.0}},
#  {'country_id': 'AUT',
#   'year': 1994,
#   'emissions': {'CO2': 61189.1,
#    'HFCs': 261.11,
#    'CH4': 9775.86,
#    'NF3': 0.76,
#    'N2O': 4279.53,
#    'PFCs': 70.96,
#    'SF6': 926.17}},
#  {'country_id': 'AUT',
#   'year': 1995,
#   'emissions': {'CO2': 64202.16,
#    'HFCs': 357.93,
#    'CH4': 9674.05,
#    'NF3': 6.44,
#    'N2O': 4389.0,
#    'PFCs': 83.35,
#    'SF6': 1100.11}},
#  {'country_id': 'AUT',
#   'year': 1996,
#   'emissions': {'CO2': 67667.26,
#    'HFCs': 420.79,
#    'CH4': 9382.93,
#    'NF3': 7.93,
#    'N2O': 4272.75,
#    'PFCs': 80.25,
#    'SF6': 1176.9}},
#  {'country_id': 'AUT',
#   'year': 1997,
#   'emissions': {'CO2': 67455.89,
#    'HFCs': 500.83,
#    'CH4': 9011.52,
#    'NF3': 15.53,
#    'N2O': 4286.76,
#    'PFCs': 117.47,
#    'SF6': 1086.4}},
#  {'country_id': 'AUT',
#   'year': 1998,
#   'emissions': {'CO2': 67047.25,
#    'HFCs': 610.34,
#    'CH4': 8831.33,
#    'NF3': 9.43,
#    'N2O': 4347.07,
#    'PFCs': 55.53,
#    'SF6': 869.88}},
#  {'country_id': 'AUT',
#   'year': 1999,
#   'emissions': {'CO2': 65660.13,
#    'HFCs': 701.82,
#    'CH4': 8645.18,
#    'NF3': 8.24,
#    'N2O': 4335.8,
#    'PFCs': 79.18,
#    'SF6': 676.37}},
#  {'country_id': 'AUT',
#   'year': 2000,
#   'emissions': {'CO2': 66274.74,
#    'HFCs': 713.63,
#    'CH4': 8466.37,
#    'NF3': 10.51,
#    'N2O': 4301.7,
#    'PFCs': 87.87,
#    'SF6': 574.53}},
#  {'country_id': 'AUT',
#   'year': 2001,
#   'emissions': {'CO2': 70299.47,
#    'HFCs': 863.1,
#    'CH4': 8284.3,
#    'NF3': 10.51,
#    'N2O': 4177.76,
#    'PFCs': 116.34,
#    'SF6': 629.33}},
#  {'country_id': 'AUT',
#   'year': 2002,
#   'emissions': {'CO2': 72126.59,
#    'HFCs': 968.78,
#    'CH4': 8134.08,
#    'NF3': 10.51,
#    'N2O': 4174.31,
#    'PFCs': 101.97,
#    'SF6': 613.3}},
#  {'country_id': 'AUT',
#   'year': 2003,
#   'emissions': {'CO2': 78023.95,
#    'HFCs': 1072.19,
#    'CH4': 8061.21,
#    'NF3': 21.56,
#    'N2O': 4163.75,
#    'PFCs': 126.38,
#    'SF6': 549.44}},
#  {'country_id': 'AUT',
#   'year': 2004,
#   'emissions': {'CO2': 78389.0,
#    'HFCs': 1158.34,
#    'CH4': 8048.71,
#    'NF3': 26.54,
#    'N2O': 3571.72,
#    'PFCs': 157.57,
#    'SF6': 484.01}},
#  {'country_id': 'AUT',
#   'year': 2005,
#   'emissions': {'CO2': 79588.5,
#    'HFCs': 1145.81,
#    'CH4': 7809.62,
#    'NF3': 28.16,
#    'N2O': 3581.49,
#    'PFCs': 163.29,
#    'SF6': 493.63}},
#  {'country_id': 'AUT',
#   'year': 2006,
#   'emissions': {'CO2': 76934.95,
#    'HFCs': 1152.47,
#    'CH4': 7667.63,
#    'NF3': 32.73,
#    'N2O': 3567.39,
#    'PFCs': 172.39,
#    'SF6': 453.46}},
#  {'country_id': 'AUT',
#   'year': 2007,
#   'emissions': {'CO2': 74268.11,
#    'HFCs': 1195.89,
#    'CH4': 7543.05,
#    'NF3': 59.39,
#    'N2O': 3577.37,
#    'PFCs': 230.33,
#    'SF6': 367.01}},
#  {'country_id': 'AUT',
#   'year': 2008,
#   'emissions': {'CO2': 74066.26,
#    'HFCs': 1248.53,
#    'CH4': 7399.36,
#    'NF3': 53.47,
#    'N2O': 3751.89,
#    'PFCs': 208.19,
#    'SF6': 373.43}},
#  {'country_id': 'AUT',
#   'year': 2009,
#   'emissions': {'CO2': 67682.73,
#    'HFCs': 1308.2,
#    'CH4': 7294.26,
#    'NF3': 4.54,
#    'N2O': 3523.22,
#    'PFCs': 36.02,
#    'SF6': 341.68}},
#  {'country_id': 'AUT',
#   'year': 2010,
#   'emissions': {'CO2': 72531.83,
#    'HFCs': 1483.19,
#    'CH4': 7182.82,
#    'NF3': 4.12,
#    'N2O': 3330.15,
#    'PFCs': 78.05,
#    'SF6': 335.87}},
#  {'country_id': 'AUT',
#   'year': 2011,
#   'emissions': {'CO2': 70327.17,
#    'HFCs': 1535.8,
#    'CH4': 6976.42,
#    'NF3': 4.1,
#    'N2O': 3402.29,
#    'PFCs': 73.51,
#    'SF6': 307.35}},
#  {'country_id': 'AUT',
#   'year': 2012,
#   'emissions': {'CO2': 67698.66,
#    'HFCs': 1612.47,
#    'CH4': 6855.14,
#    'NF3': 8.56,
#    'N2O': 3359.69,
#    'PFCs': 50.72,
#    'SF6': 311.88}},
#  {'country_id': 'AUT',
#   'year': 2013,
#   'emissions': {'CO2': 67957.12,
#    'HFCs': 1602.6,
#    'CH4': 6757.49,
#    'NF3': 9.75,
#    'N2O': 3361.48,
#    'PFCs': 49.23,
#    'SF6': 304.87}},
#  {'country_id': 'AUT',
#   'year': 2014,
#   'emissions': {'CO2': 64262.56,
#    'HFCs': 1642.8,
#    'CH4': 6623.27,
#    'NF3': 10.56,
#    'N2O': 3427.44,
#    'PFCs': 53.03,
#    'SF6': 312.96}},
#  {'country_id': 'BEL',
#   'year': 1990,
#   'emissions': {'CO2': 119982.5,
#    'CH4': 12040.18,
#    'N2O': 10232.4,
#    'PFCs': 2191.05,
#    'SF6': 1575.1}},
#  {'country_id': 'BEL',
#   'year': 1991,
#   'emissions': {'CO2': 123130.65,
#    'CH4': 11999.38,
#    'N2O': 10106.41,
#    'PFCs': 2096.42,
#    'SF6': 1492.84}},
#  {'country_id': 'BEL',
#   'year': 1992,
#   'emissions': {'CO2': 122217.92,
#    'HFCs': 484.3,
#    'CH4': 11886.35,
#    'N2O': 9858.7,
#    'PFCs': 2284.77,
#    'SF6': 1652.69}},
#  {'country_id': 'BEL',
#   'year': 1993,
#   'emissions': {'CO2': 121156.96,
#    'HFCs': 484.3,
#    'CH4': 11838.3,
#    'N2O': 10129.39,
#    'PFCs': 2195.9,
#    'SF6': 1588.53}},
#  {'country_id': 'BEL',
#   'year': 1994,
#   'emissions': {'CO2': 124426.89,
#    'HFCs': 495.79,
#    'CH4': 11867.02,
#    'N2O': 10524.5,
#    'PFCs': 2637.37,
#    'SF6': 1930.81}},
#  {'country_id': 'BEL',
#   'year': 1995,
#   'emissions': {'CO2': 125519.44,
#    'HFCs': 501.99,
#    'CH4': 11947.64,
#    'N2O': 10997.2,
#    'PFCs': 2914.29,
#    'SF6': 2139.73}},
#  {'country_id': 'BEL',
#   'year': 1996,
#   'emissions': {'CO2': 129010.47,
#    'HFCs': 602.2,
#    'CH4': 11802.08,
#    'N2O': 11415.4,
#    'PFCs': 2766.91,
#    'SF6': 2059.62}},
#  {'country_id': 'BEL',
#   'year': 1997,
#   'emissions': {'CO2': 123495.74,
#    'HFCs': 726.99,
#    'CH4': 11689.9,
#    'N2O': 11183.05,
#    'PFCs': 1528.92,
#    'SF6': 538.85}},
#  {'country_id': 'BEL',
#   'year': 1998,
#   'emissions': {'CO2': 129737.09,
#    'HFCs': 881.22,
#    'CH4': 11525.0,
#    'N2O': 11057.26,
#    'PFCs': 843.87,
#    'SF6': 295.95}},
#  {'country_id': 'BEL',
#   'year': 1999,
#   'emissions': {'CO2': 124208.07,
#    'HFCs': 935.58,
#    'CH4': 11265.28,
#    'N2O': 11071.1,
#    'PFCs': 428.75,
#    'SF6': 153.66}},
#  {'country_id': 'BEL',
#   'year': 2000,
#   'emissions': {'CO2': 126315.21,
#    'HFCs': 1127.8,
#    'CH4': 10827.0,
#    'N2O': 10352.83,
#    'PFCs': 446.11,
#    'SF6': 144.06}},
#  {'country_id': 'BEL',
#   'year': 2001,
#   'emissions': {'CO2': 125649.37,
#    'HFCs': 1211.53,
#    'CH4': 10386.25,
#    'N2O': 9963.92,
#    'PFCs': 275.84,
#    'SF6': 139.22}},
#  {'country_id': 'BEL',
#   'year': 2002,
#   'emissions': {'CO2': 126015.19,
#    'HFCs': 1438.42,
#    'CH4': 9956.5,
#    'N2O': 9613.02,
#    'PFCs': 101.06,
#    'SF6': 116.17}},
#  {'country_id': 'BEL',
#   'year': 2003,
#   'emissions': {'CO2': 127523.99,
#    'HFCs': 1608.87,
#    'CH4': 9372.47,
#    'N2O': 8712.78,
#    'PFCs': 259.03,
#    'SF6': 101.93}},
#  {'country_id': 'BEL',
#   'year': 2004,
#   'emissions': {'CO2': 128640.48,
#    'HFCs': 1693.4,
#    'CH4': 9318.58,
#    'N2O': 8850.41,
#    'PFCs': 378.33,
#    'SF6': 90.2}},
#  {'country_id': 'BEL',
#   'year': 2005,
#   'emissions': {'CO2': 125118.02,
#    'HFCs': 1745.35,
#    'CH4': 9074.77,
#    'N2O': 8581.49,
#    'PFCs': 192.77,
#    'SF6': 90.69}},
#  {'country_id': 'BEL',
#   'year': 2006,
#   'emissions': {'CO2': 122319.59,
#    'HFCs': 1876.64,
#    'CH4': 8982.98,
#    'N2O': 7591.03,
#    'PFCs': 199.91,
#    'SF6': 76.55}},
#  {'country_id': 'BEL',
#   'year': 2007,
#   'emissions': {'CO2': 118027.41,
#    'HFCs': 2079.1,
#    'CH4': 8947.76,
#    'N2O': 7094.15,
#    'PFCs': 224.06,
#    'SF6': 78.86}},
#  {'country_id': 'BEL',
#   'year': 2008,
#   'emissions': {'CO2': 120362.61,
#    'HFCs': 2206.76,
#    'CH4': 8736.79,
#    'NF3': 0.67,
#    'N2O': 7102.8,
#    'PFCs': 253.1,
#    'SF6': 86.88}},
#  {'country_id': 'BEL',
#   'year': 2009,
#   'emissions': {'CO2': 107282.54,
#    'HFCs': 2391.46,
#    'CH4': 8668.57,
#    'NF3': 0.57,
#    'N2O': 7229.43,
#    'PFCs': 145.92,
#    'SF6': 93.31}},
#  {'country_id': 'BEL',
#   'year': 2010,
#   'emissions': {'CO2': 114155.39,
#    'HFCs': 2508.71,
#    'CH4': 8624.5,
#    'NF3': 1.32,
#    'N2O': 7759.83,
#    'PFCs': 106.61,
#    'SF6': 102.03}},
#  {'country_id': 'BEL',
#   'year': 2011,
#   'emissions': {'CO2': 104945.71,
#    'HFCs': 2614.05,
#    'CH4': 8369.07,
#    'NF3': 2.48,
#    'N2O': 6564.49,
#    'PFCs': 225.5,
#    'SF6': 112.09}},
#  {'country_id': 'BEL',
#   'year': 2012,
#   'emissions': {'CO2': 100931.6,
#    'HFCs': 2733.36,
#    'CH4': 8235.74,
#    'NF3': 1.12,
#    'N2O': 6470.89,
#    'PFCs': 278.21,
#    'SF6': 110.43}},
#  {'country_id': 'BEL',
#   'year': 2013,
#   'emissions': {'CO2': 101744.74,
#    'HFCs': 2703.01,
#    'CH4': 8098.25,
#    'NF3': 1.24,
#    'N2O': 6280.72,
#    'PFCs': 431.59,
#    'SF6': 115.75}},
#  {'country_id': 'BEL',
#   'year': 2014,
#   'emissions': {'CO2': 96325.41,
#    'HFCs': 2811.8,
#    'CH4': 8047.55,
#    'NF3': 0.69,
#    'N2O': 6278.98,
#    'PFCs': 306.96,
#    'SF6': 95.22}},
#  {'country_id': 'BGR',
#   'year': 1990,
#   'emissions': {'CO2': 78197.88,
#    'CH4': 16430.84,
#    'N2O': 8818.37,
#    'SF6': 3.69}},
#  {'country_id': 'BGR',
#   'year': 1991,
#   'emissions': {'CO2': 59769.34,
#    'HFCs': 0.0,
#    'CH4': 15313.27,
#    'N2O': 6839.5,
#    'SF6': 3.91}},
#  {'country_id': 'BGR',
#   'year': 1992,
#   'emissions': {'CO2': 56551.59,
#    'HFCs': 0.01,
#    'CH4': 14869.3,
#    'N2O': 5774.31,
#    'SF6': 4.13}},
#  {'country_id': 'BGR',
#   'year': 1993,
#   'emissions': {'CO2': 57203.94,
#    'HFCs': 0.02,
#    'CH4': 13764.49,
#    'N2O': 5222.47,
#    'SF6': 4.37}},
#  {'country_id': 'BGR',
#   'year': 1994,
#   'emissions': {'CO2': 55649.08,
#    'HFCs': 2.16,
#    'CH4': 12003.09,
#    'N2O': 5106.66,
#    'SF6': 4.63}},
#  {'country_id': 'BGR',
#   'year': 1995,
#   'emissions': {'CO2': 57221.61,
#    'HFCs': 6.59,
#    'CH4': 12051.21,
#    'N2O': 4977.78,
#    'SF6': 4.9}},
#  {'country_id': 'BGR',
#   'year': 1996,
#   'emissions': {'CO2': 57581.19,
#    'HFCs': 11.55,
#    'CH4': 11936.17,
#    'N2O': 4846.99,
#    'SF6': 5.18}},
#  {'country_id': 'BGR',
#   'year': 1997,
#   'emissions': {'CO2': 54790.13,
#    'HFCs': 18.36,
#    'CH4': 11500.65,
#    'N2O': 4589.8,
#    'SF6': 5.48}},
#  {'country_id': 'BGR',
#   'year': 1998,
#   'emissions': {'CO2': 52143.36,
#    'HFCs': 28.72,
#    'CH4': 10886.06,
#    'N2O': 3784.73,
#    'SF6': 5.8}},
#  {'country_id': 'BGR',
#   'year': 1999,
#   'emissions': {'CO2': 45751.79,
#    'HFCs': 40.99,
#    'CH4': 10347.04,
#    'N2O': 3944.16,
#    'SF6': 6.14}},
#  {'country_id': 'BGR',
#   'year': 2000,
#   'emissions': {'CO2': 44896.67,
#    'HFCs': 57.33,
#    'CH4': 10189.34,
#    'N2O': 4005.22,
#    'SF6': 6.49}},
#  {'country_id': 'BGR',
#   'year': 2001,
#   'emissions': {'CO2': 48568.92,
#    'HFCs': 75.17,
#    'CH4': 9491.67,
#    'N2O': 4078.71,
#    'SF6': 6.87}},
#  {'country_id': 'BGR',
#   'year': 2002,
#   'emissions': {'CO2': 45786.29,
#    'HFCs': 96.6,
#    'CH4': 9374.21,
#    'N2O': 4017.63,
#    'SF6': 7.27}},
#  {'country_id': 'BGR',
#   'year': 2003,
#   'emissions': {'CO2': 49971.15,
#    'HFCs': 126.5,
#    'CH4': 10063.72,
#    'N2O': 3852.3,
#    'SF6': 7.69}},
#  {'country_id': 'BGR',
#   'year': 2004,
#   'emissions': {'CO2': 49170.34,
#    'HFCs': 180.34,
#    'CH4': 9476.24,
#    'N2O': 4395.68,
#    'SF6': 8.13}},
#  {'country_id': 'BGR',
#   'year': 2005,
#   'emissions': {'CO2': 50191.12,
#    'HFCs': 298.76,
#    'CH4': 8720.08,
#    'N2O': 4240.78,
#    'SF6': 8.16}},
#  {'country_id': 'BGR',
#   'year': 2006,
#   'emissions': {'CO2': 51446.28,
#    'HFCs': 447.16,
#    'CH4': 8446.73,
#    'N2O': 3769.74,
#    'SF6': 8.48}},
#  {'country_id': 'BGR',
#   'year': 2007,
#   'emissions': {'CO2': 55184.42,
#    'HFCs': 545.2,
#    'CH4': 8389.98,
#    'N2O': 3814.0,
#    'SF6': 8.81}},
#  {'country_id': 'BGR',
#   'year': 2008,
#   'emissions': {'CO2': 53655.14,
#    'HFCs': 841.84,
#    'CH4': 8164.03,
#    'N2O': 4055.13,
#    'PFCs': 0.02,
#    'SF6': 9.16}},
#  {'country_id': 'BGR',
#   'year': 2009,
#   'emissions': {'CO2': 45487.87,
#    'HFCs': 897.32,
#    'CH4': 7794.84,
#    'N2O': 3646.36,
#    'PFCs': 0.06,
#    'SF6': 9.52}},
#  {'country_id': 'BGR',
#   'year': 2010,
#   'emissions': {'CO2': 47678.65,
#    'HFCs': 927.07,
#    'CH4': 7782.64,
#    'N2O': 4118.31,
#    'PFCs': 0.06,
#    'SF6': 12.47}},
#  {'country_id': 'BGR',
#   'year': 2011,
#   'emissions': {'CO2': 53020.98,
#    'HFCs': 1038.93,
#    'CH4': 8015.2,
#    'N2O': 3768.25,
#    'PFCs': 0.06,
#    'SF6': 14.19}},
#  {'country_id': 'BGR',
#   'year': 2012,
#   'emissions': {'CO2': 48117.56,
#    'HFCs': 1109.36,
#    'CH4': 7643.92,
#    'N2O': 3833.32,
#    'PFCs': 0.05,
#    'SF6': 19.29}},
#  {'country_id': 'BGR',
#   'year': 2013,
#   'emissions': {'CO2': 42534.93,
#    'HFCs': 1277.86,
#    'CH4': 7526.89,
#    'N2O': 4237.59,
#    'PFCs': 0.04,
#    'SF6': 19.72}},
#  {'country_id': 'BGR',
#   'year': 2014,
#   'emissions': {'CO2': 45139.96,
#    'HFCs': 1423.81,
#    'CH4': 7420.51,
#    'N2O': 3807.67,
#    'PFCs': 0.03,
#    'SF6': 15.62}},
#  {'country_id': 'BLR',
#   'year': 1990,
#   'emissions': {'CO2': 100438.1, 'CH4': 17944.37, 'N2O': 15074.7}},
#  {'country_id': 'BLR',
#   'year': 1991,
#   'emissions': {'CO2': 93649.17, 'CH4': 17258.13, 'N2O': 14693.75}},
#  {'country_id': 'BLR',
#   'year': 1992,
#   'emissions': {'CO2': 87060.81, 'CH4': 16295.44, 'N2O': 13232.44}},
#  {'country_id': 'BLR',
#   'year': 1993,
#   'emissions': {'CO2': 75551.76, 'CH4': 15583.11, 'N2O': 12816.66}},
#  {'country_id': 'BLR',
#   'year': 1994,
#   'emissions': {'CO2': 62402.28, 'CH4': 14331.81, 'N2O': 11472.27}},
#  {'country_id': 'BLR',
#   'year': 1995,
#   'emissions': {'CO2': 56005.94,
#    'CH4': 13611.08,
#    'N2O': 10752.77,
#    'SF6': 0.0}},
#  {'country_id': 'BLR',
#   'year': 1996,
#   'emissions': {'CO2': 57251.36,
#    'CH4': 13672.82,
#    'N2O': 11451.01,
#    'SF6': 0.01}},
#  {'country_id': 'BLR',
#   'year': 1997,
#   'emissions': {'CO2': 60971.82,
#    'CH4': 13578.27,
#    'N2O': 11732.37,
#    'SF6': 0.06}},
#  {'country_id': 'BLR',
#   'year': 1998,
#   'emissions': {'CO2': 57426.33,
#    'CH4': 13540.24,
#    'N2O': 11702.19,
#    'SF6': 0.07}},
#  {'country_id': 'BLR',
#   'year': 1999,
#   'emissions': {'CO2': 55033.95,
#    'CH4': 13212.46,
#    'N2O': 11251.34,
#    'SF6': 0.09}},
#  {'country_id': 'BLR',
#   'year': 2000,
#   'emissions': {'CO2': 53686.86, 'CH4': 12922.7, 'N2O': 11350.07, 'SF6': 0.1}},
#  {'country_id': 'BLR',
#   'year': 2001,
#   'emissions': {'CO2': 53783.85,
#    'CH4': 12799.03,
#    'N2O': 11338.84,
#    'SF6': 0.11}},
#  {'country_id': 'BLR',
#   'year': 2002,
#   'emissions': {'CO2': 53843.7,
#    'CH4': 12705.36,
#    'N2O': 10134.69,
#    'SF6': 0.12}},
#  {'country_id': 'BLR',
#   'year': 2003,
#   'emissions': {'CO2': 54845.15,
#    'CH4': 13734.63,
#    'N2O': 10578.78,
#    'SF6': 0.16}},
#  {'country_id': 'BLR',
#   'year': 2004,
#   'emissions': {'CO2': 58457.65,
#    'CH4': 14331.37,
#    'N2O': 10899.04,
#    'SF6': 0.24}},
#  {'country_id': 'BLR',
#   'year': 2005,
#   'emissions': {'CO2': 59664.74,
#    'CH4': 14727.06,
#    'N2O': 11203.95,
#    'SF6': 0.35}},
#  {'country_id': 'BLR',
#   'year': 2006,
#   'emissions': {'CO2': 62229.4,
#    'CH4': 15450.08,
#    'N2O': 11769.73,
#    'SF6': 0.45}},
#  {'country_id': 'BLR',
#   'year': 2007,
#   'emissions': {'CO2': 61563.88,
#    'CH4': 15646.79,
#    'N2O': 11709.43,
#    'SF6': 0.54}},
#  {'country_id': 'BLR',
#   'year': 2008,
#   'emissions': {'CO2': 63846.1,
#    'CH4': 16240.16,
#    'N2O': 12276.83,
#    'SF6': 1.25}},
#  {'country_id': 'BLR',
#   'year': 2009,
#   'emissions': {'CO2': 59596.21,
#    'CH4': 17118.03,
#    'N2O': 12507.97,
#    'SF6': 1.45}},
#  {'country_id': 'BLR',
#   'year': 2010,
#   'emissions': {'CO2': 61632.49,
#    'CH4': 17109.27,
#    'N2O': 12439.69,
#    'SF6': 2.1}},
#  {'country_id': 'BLR',
#   'year': 2011,
#   'emissions': {'CO2': 61128.4, 'CH4': 17499.48, 'N2O': 13041.55, 'SF6': 2.3}},
#  {'country_id': 'BLR',
#   'year': 2012,
#   'emissions': {'CO2': 60636.85,
#    'CH4': 17461.77,
#    'N2O': 12824.04,
#    'SF6': 2.46}},
#  {'country_id': 'BLR',
#   'year': 2013,
#   'emissions': {'CO2': 61510.99,
#    'CH4': 18724.36,
#    'N2O': 12799.39,
#    'SF6': 2.51}},
#  {'country_id': 'BLR',
#   'year': 2014,
#   'emissions': {'CO2': 60615.65,
#    'CH4': 18599.18,
#    'N2O': 12678.39,
#    'SF6': 2.43}},
#  {'country_id': 'CAN',
#   'year': 1990,
#   'emissions': {'CO2': 463493.33,
#    'HFCs': 970.58,
#    'CH4': 95378.25,
#    'NF3': 0.32,
#    'N2O': 42239.73,
#    'PFCs': 7557.9,
#    'SF6': 3225.93}},
#  {'country_id': 'CAN',
#   'year': 1991,
#   'emissions': {'CO2': 454246.14,
#    'HFCs': 1056.72,
#    'CH4': 97516.51,
#    'NF3': 0.32,
#    'N2O': 41010.07,
#    'PFCs': 8033.11,
#    'SF6': 3685.24}},
#  {'country_id': 'CAN',
#   'year': 1992,
#   'emissions': {'CO2': 468546.46,
#    'HFCs': 829.84,
#    'CH4': 101927.84,
#    'NF3': 0.31,
#    'N2O': 41323.52,
#    'PFCs': 7578.68,
#    'SF6': 2557.12}},
#  {'country_id': 'CAN',
#   'year': 1993,
#   'emissions': {'CO2': 467607.24,
#    'CH4': 105204.36,
#    'NF3': 0.3,
#    'N2O': 42000.45,
#    'PFCs': 7455.58,
#    'SF6': 2373.55}},
#  {'country_id': 'CAN',
#   'year': 1994,
#   'emissions': {'CO2': 482691.67,
#    'CH4': 108917.32,
#    'NF3': 0.29,
#    'N2O': 45062.17,
#    'PFCs': 6895.01,
#    'SF6': 2441.74}},
#  {'country_id': 'CAN',
#   'year': 1995,
#   'emissions': {'CO2': 497224.84,
#    'HFCs': 693.37,
#    'CH4': 113111.08,
#    'NF3': 0.28,
#    'N2O': 45650.33,
#    'PFCs': 6349.22,
#    'SF6': 2275.16}},
#  {'country_id': 'CAN',
#   'year': 1996,
#   'emissions': {'CO2': 510619.68,
#    'HFCs': 1165.51,
#    'CH4': 116885.46,
#    'NF3': 0.27,
#    'N2O': 47724.4,
#    'PFCs': 6502.75,
#    'SF6': 1768.65}},
#  {'country_id': 'CAN',
#   'year': 1997,
#   'emissions': {'CO2': 525120.01,
#    'HFCs': 1568.53,
#    'CH4': 118988.19,
#    'NF3': 0.26,
#    'N2O': 46527.87,
#    'PFCs': 6374.9,
#    'SF6': 1827.63}},
#  {'country_id': 'CAN',
#   'year': 1998,
#   'emissions': {'CO2': 533794.45,
#    'HFCs': 2172.32,
#    'CH4': 120647.46,
#    'NF3': 0.26,
#    'N2O': 42548.87,
#    'PFCs': 6477.23,
#    'SF6': 2357.49}},
#  {'country_id': 'CAN',
#   'year': 1999,
#   'emissions': {'CO2': 550183.06,
#    'HFCs': 2806.0,
#    'CH4': 120592.53,
#    'NF3': 0.25,
#    'N2O': 40309.52,
#    'PFCs': 5371.79,
#    'SF6': 2410.1}},
#  {'country_id': 'CAN',
#   'year': 2000,
#   'emissions': {'CO2': 572290.39,
#    'HFCs': 3400.33,
#    'CH4': 120724.87,
#    'NF3': 0.24,
#    'N2O': 39936.36,
#    'PFCs': 4985.57,
#    'SF6': 2902.96}},
#  {'country_id': 'CAN',
#   'year': 2001,
#   'emissions': {'CO2': 564617.02,
#    'HFCs': 3787.73,
#    'CH4': 119920.26,
#    'NF3': 0.23,
#    'N2O': 38523.21,
#    'PFCs': 4048.63,
#    'SF6': 2557.11}},
#  {'country_id': 'CAN',
#   'year': 2002,
#   'emissions': {'CO2': 569862.15,
#    'HFCs': 4270.19,
#    'CH4': 117504.64,
#    'NF3': 0.22,
#    'N2O': 38156.77,
#    'PFCs': 3463.01,
#    'SF6': 3015.81}},
#  {'country_id': 'CAN',
#   'year': 2003,
#   'emissions': {'CO2': 587306.68,
#    'HFCs': 4615.42,
#    'CH4': 116809.28,
#    'NF3': 0.21,
#    'N2O': 40097.53,
#    'PFCs': 3490.09,
#    'SF6': 2651.44}},
#  {'country_id': 'CAN',
#   'year': 2004,
#   'emissions': {'CO2': 585414.86,
#    'HFCs': 5215.23,
#    'CH4': 117419.39,
#    'NF3': 0.2,
#    'N2O': 42328.24,
#    'PFCs': 3522.38,
#    'SF6': 2339.91}},
#  {'country_id': 'CAN',
#   'year': 2005,
#   'emissions': {'CO2': 579225.34,
#    'HFCs': 5677.88,
#    'CH4': 116434.33,
#    'NF3': 0.19,
#    'N2O': 40863.43,
#    'PFCs': 3839.26,
#    'SF6': 1417.36}},
#  {'country_id': 'CAN',
#   'year': 2006,
#   'emissions': {'CO2': 573479.27,
#    'HFCs': 5828.27,
#    'CH4': 115516.05,
#    'NF3': 0.19,
#    'N2O': 38759.94,
#    'PFCs': 2986.03,
#    'SF6': 1526.74}},
#  {'country_id': 'CAN',
#   'year': 2007,
#   'emissions': {'CO2': 596041.32,
#    'HFCs': 6222.87,
#    'CH4': 113213.99,
#    'NF3': 0.18,
#    'N2O': 39691.97,
#    'PFCs': 2534.66,
#    'SF6': 726.19}},
#  {'country_id': 'CAN',
#   'year': 2008,
#   'emissions': {'CO2': 577444.93,
#    'HFCs': 6123.52,
#    'CH4': 110540.26,
#    'NF3': 0.17,
#    'N2O': 41681.65,
#    'PFCs': 2601.86,
#    'SF6': 644.35}},
#  {'country_id': 'CAN',
#   'year': 2009,
#   'emissions': {'CO2': 542829.46,
#    'HFCs': 6698.96,
#    'CH4': 106149.44,
#    'NF3': 0.16,
#    'N2O': 37749.59,
#    'PFCs': 2510.72,
#    'SF6': 373.87}},
#  {'country_id': 'CAN',
#   'year': 2010,
#   'emissions': {'CO2': 555003.76,
#    'HFCs': 7477.17,
#    'CH4': 103730.44,
#    'NF3': 0.15,
#    'N2O': 37891.75,
#    'PFCs': 1859.18,
#    'SF6': 440.42}},
#  {'country_id': 'CAN',
#   'year': 2011,
#   'emissions': {'CO2': 558152.72,
#    'HFCs': 7991.64,
#    'CH4': 103884.67,
#    'NF3': 0.15,
#    'N2O': 37652.73,
#    'PFCs': 1687.38,
#    'SF6': 395.18}},
#  {'country_id': 'CAN',
#   'year': 2012,
#   'emissions': {'CO2': 563423.61,
#    'HFCs': 8277.68,
#    'CH4': 105633.62,
#    'NF3': 0.15,
#    'N2O': 38773.54,
#    'PFCs': 1798.64,
#    'SF6': 439.63}},
#  {'country_id': 'CAN',
#   'year': 2013,
#   'emissions': {'CO2': 573094.04,
#    'HFCs': 8564.62,
#    'CH4': 107063.13,
#    'NF3': 0.15,
#    'N2O': 40647.06,
#    'PFCs': 1617.1,
#    'SF6': 437.98}},
#  {'country_id': 'CAN',
#   'year': 2014,
#   'emissions': {'CO2': 574099.78,
#    'HFCs': 9024.46,
#    'CH4': 108436.72,
#    'NF3': 0.15,
#    'N2O': 39407.11,
#    'PFCs': 1088.04,
#    'SF6': 362.63}},
#  {'country_id': 'CHE',
#   'year': 1990,
#   'emissions': {'CO2': 44115.53,
#    'HFCs': 0.02,
#    'CH4': 6086.29,
#    'N2O': 2852.38,
#    'PFCs': 116.52,
#    'SF6': 137.01}},
#  {'country_id': 'CHE',
#   'year': 1991,
#   'emissions': {'CO2': 46144.81,
#    'HFCs': 1.59,
#    'CH4': 6023.59,
#    'N2O': 2845.88,
#    'PFCs': 98.51,
#    'SF6': 139.21}},
#  {'country_id': 'CHE',
#   'year': 1992,
#   'emissions': {'CO2': 45974.7,
#    'HFCs': 15.68,
#    'CH4': 5943.52,
#    'N2O': 2814.45,
#    'PFCs': 80.61,
#    'SF6': 141.39}},
#  {'country_id': 'CHE',
#   'year': 1993,
#   'emissions': {'CO2': 43556.28,
#    'HFCs': 32.79,
#    'CH4': 5835.38,
#    'N2O': 2748.12,
#    'PFCs': 34.7,
#    'SF6': 120.53}},
#  {'country_id': 'CHE',
#   'year': 1994,
#   'emissions': {'CO2': 42613.3,
#    'HFCs': 81.68,
#    'CH4': 5783.91,
#    'N2O': 2718.08,
#    'PFCs': 20.87,
#    'SF6': 106.89}},
#  {'country_id': 'CHE',
#   'year': 1995,
#   'emissions': {'CO2': 43368.46,
#    'HFCs': 245.9,
#    'CH4': 5776.09,
#    'N2O': 2703.57,
#    'PFCs': 17.49,
#    'SF6': 93.23}},
#  {'country_id': 'CHE',
#   'year': 1996,
#   'emissions': {'CO2': 44088.33,
#    'HFCs': 297.55,
#    'CH4': 5736.94,
#    'N2O': 2699.74,
#    'PFCs': 20.42,
#    'SF6': 90.07}},
#  {'country_id': 'CHE',
#   'year': 1997,
#   'emissions': {'CO2': 42971.62,
#    'HFCs': 361.69,
#    'CH4': 5594.11,
#    'N2O': 2604.88,
#    'PFCs': 21.03,
#    'SF6': 124.24}},
#  {'country_id': 'CHE',
#   'year': 1998,
#   'emissions': {'CO2': 44522.37,
#    'HFCs': 456.53,
#    'CH4': 5523.55,
#    'N2O': 2600.54,
#    'PFCs': 23.83,
#    'SF6': 152.61}},
#  {'country_id': 'CHE',
#   'year': 1999,
#   'emissions': {'CO2': 44354.54,
#    'HFCs': 530.46,
#    'CH4': 5422.28,
#    'N2O': 2564.81,
#    'PFCs': 25.58,
#    'SF6': 139.91}},
#  {'country_id': 'CHE',
#   'year': 2000,
#   'emissions': {'CO2': 43545.96,
#    'HFCs': 625.94,
#    'CH4': 5388.97,
#    'N2O': 2561.2,
#    'PFCs': 49.9,
#    'SF6': 143.79}},
#  {'country_id': 'CHE',
#   'year': 2001,
#   'emissions': {'CO2': 45002.28,
#    'HFCs': 723.99,
#    'CH4': 5429.09,
#    'N2O': 2577.45,
#    'PFCs': 27.82,
#    'SF6': 144.78}},
#  {'country_id': 'CHE',
#   'year': 2002,
#   'emissions': {'CO2': 43373.99,
#    'HFCs': 803.18,
#    'CH4': 5395.27,
#    'N2O': 2554.43,
#    'PFCs': 32.87,
#    'SF6': 158.36}},
#  {'country_id': 'CHE',
#   'year': 2003,
#   'emissions': {'CO2': 44587.98,
#    'HFCs': 898.48,
#    'CH4': 5317.73,
#    'N2O': 2507.1,
#    'PFCs': 61.67,
#    'SF6': 164.58}},
#  {'country_id': 'CHE',
#   'year': 2004,
#   'emissions': {'CO2': 45149.67,
#    'HFCs': 1020.51,
#    'CH4': 5285.85,
#    'N2O': 2466.25,
#    'PFCs': 65.31,
#    'SF6': 186.09}},
#  {'country_id': 'CHE',
#   'year': 2005,
#   'emissions': {'CO2': 45778.09,
#    'HFCs': 1071.19,
#    'CH4': 5302.88,
#    'N2O': 2458.51,
#    'PFCs': 44.19,
#    'SF6': 203.19}},
#  {'country_id': 'CHE',
#   'year': 2006,
#   'emissions': {'CO2': 45351.17,
#    'HFCs': 1118.3,
#    'CH4': 5316.96,
#    'N2O': 2457.95,
#    'PFCs': 51.53,
#    'SF6': 185.64}},
#  {'country_id': 'CHE',
#   'year': 2007,
#   'emissions': {'CO2': 43360.39,
#    'HFCs': 1193.91,
#    'CH4': 5296.65,
#    'N2O': 2483.67,
#    'PFCs': 49.11,
#    'SF6': 171.6}},
#  {'country_id': 'CHE',
#   'year': 2008,
#   'emissions': {'CO2': 44676.94,
#    'HFCs': 1243.1,
#    'CH4': 5375.41,
#    'NF3': 0.08,
#    'N2O': 2508.84,
#    'PFCs': 57.91,
#    'SF6': 222.16}},
#  {'country_id': 'CHE',
#   'year': 2009,
#   'emissions': {'CO2': 43509.09,
#    'HFCs': 1253.07,
#    'CH4': 5292.03,
#    'NF3': 5.1,
#    'N2O': 2474.37,
#    'PFCs': 62.99,
#    'SF6': 179.65}},
#  {'country_id': 'CHE',
#   'year': 2010,
#   'emissions': {'CO2': 45027.06,
#    'HFCs': 1329.36,
#    'CH4': 5271.58,
#    'NF3': 8.45,
#    'N2O': 2524.08,
#    'PFCs': 64.57,
#    'SF6': 147.98}},
#  {'country_id': 'CHE',
#   'year': 2011,
#   'emissions': {'CO2': 40973.15,
#    'HFCs': 1410.15,
#    'CH4': 5206.27,
#    'NF3': 6.22,
#    'N2O': 2473.2,
#    'PFCs': 67.78,
#    'SF6': 159.53}},
#  {'country_id': 'CHE',
#   'year': 2012,
#   'emissions': {'CO2': 42241.55,
#    'HFCs': 1489.05,
#    'CH4': 5164.96,
#    'NF3': 0.36,
#    'N2O': 2461.36,
#    'PFCs': 71.33,
#    'SF6': 208.91}},
#  {'country_id': 'CHE',
#   'year': 2013,
#   'emissions': {'CO2': 43181.66,
#    'HFCs': 1513.19,
#    'CH4': 5095.05,
#    'NF3': 0.09,
#    'N2O': 2425.57,
#    'PFCs': 51.96,
#    'SF6': 252.46}},
#  {'country_id': 'CHE',
#   'year': 2014,
#   'emissions': {'CO2': 39265.05,
#    'HFCs': 1500.98,
#    'CH4': 5095.07,
#    'NF3': 0.4,
#    'N2O': 2452.85,
#    'PFCs': 43.88,
#    'SF6': 258.84}},
#  {'country_id': 'CYP',
#   'year': 1990,
#   'emissions': {'CO2': 4621.01,
#    'HFCs': 0.15,
#    'CH4': 693.57,
#    'N2O': 309.9,
#    'SF6': 0.03}},
#  {'country_id': 'CYP',
#   'year': 1991,
#   'emissions': {'CO2': 5107.08,
#    'HFCs': 0.16,
#    'CH4': 704.36,
#    'N2O': 309.9,
#    'SF6': 0.03}},
#  {'country_id': 'CYP',
#   'year': 1992,
#   'emissions': {'CO2': 5482.97,
#    'HFCs': 0.16,
#    'CH4': 733.57,
#    'N2O': 342.59,
#    'SF6': 0.03}},
#  {'country_id': 'CYP',
#   'year': 1993,
#   'emissions': {'CO2': 5733.67,
#    'HFCs': 0.22,
#    'CH4': 761.68,
#    'N2O': 363.13,
#    'SF6': 0.04}},
#  {'country_id': 'CYP',
#   'year': 1994,
#   'emissions': {'CO2': 5977.26,
#    'HFCs': 0.7,
#    'CH4': 773.18,
#    'N2O': 351.95,
#    'SF6': 0.05}},
#  {'country_id': 'CYP',
#   'year': 1995,
#   'emissions': {'CO2': 5848.04,
#    'HFCs': 2.7,
#    'CH4': 797.53,
#    'N2O': 398.6,
#    'SF6': 0.06}},
#  {'country_id': 'CYP',
#   'year': 1996,
#   'emissions': {'CO2': 6156.13,
#    'HFCs': 3.61,
#    'CH4': 819.08,
#    'N2O': 364.65,
#    'SF6': 0.07}},
#  {'country_id': 'CYP',
#   'year': 1997,
#   'emissions': {'CO2': 6287.03,
#    'HFCs': 6.09,
#    'CH4': 826.65,
#    'N2O': 353.26,
#    'SF6': 0.07}},
#  {'country_id': 'CYP',
#   'year': 1998,
#   'emissions': {'CO2': 6580.3,
#    'HFCs': 9.38,
#    'CH4': 830.27,
#    'N2O': 379.55,
#    'SF6': 0.07}},
#  {'country_id': 'CYP',
#   'year': 1999,
#   'emissions': {'CO2': 6847.66,
#    'HFCs': 14.14,
#    'CH4': 831.09,
#    'N2O': 366.12,
#    'SF6': 0.07}},
#  {'country_id': 'CYP',
#   'year': 2000,
#   'emissions': {'CO2': 7095.96,
#    'HFCs': 20.38,
#    'CH4': 847.45,
#    'N2O': 363.02,
#    'SF6': 0.08}},
#  {'country_id': 'CYP',
#   'year': 2001,
#   'emissions': {'CO2': 6969.47,
#    'HFCs': 30.85,
#    'CH4': 887.6,
#    'N2O': 394.56,
#    'SF6': 0.08}},
#  {'country_id': 'CYP',
#   'year': 2002,
#   'emissions': {'CO2': 7160.39,
#    'HFCs': 41.19,
#    'CH4': 921.25,
#    'N2O': 396.17,
#    'SF6': 0.08}},
#  {'country_id': 'CYP',
#   'year': 2003,
#   'emissions': {'CO2': 7550.08,
#    'HFCs': 52.54,
#    'CH4': 917.71,
#    'N2O': 394.17,
#    'SF6': 0.09}},
#  {'country_id': 'CYP',
#   'year': 2004,
#   'emissions': {'CO2': 7776.91,
#    'HFCs': 67.18,
#    'CH4': 914.71,
#    'N2O': 385.47,
#    'SF6': 0.1}},
#  {'country_id': 'CYP',
#   'year': 2005,
#   'emissions': {'CO2': 7961.98,
#    'HFCs': 92.6,
#    'CH4': 894.25,
#    'N2O': 359.03,
#    'SF6': 0.12}},
#  {'country_id': 'CYP',
#   'year': 2006,
#   'emissions': {'CO2': 8152.49,
#    'HFCs': 144.71,
#    'CH4': 894.04,
#    'N2O': 376.18,
#    'SF6': 0.12}},
#  {'country_id': 'CYP',
#   'year': 2007,
#   'emissions': {'CO2': 8458.66,
#    'HFCs': 169.82,
#    'CH4': 915.52,
#    'N2O': 369.09,
#    'SF6': 0.14}},
#  {'country_id': 'CYP',
#   'year': 2008,
#   'emissions': {'CO2': 8620.4,
#    'HFCs': 195.31,
#    'CH4': 919.1,
#    'N2O': 358.32,
#    'SF6': 0.15}},
#  {'country_id': 'CYP',
#   'year': 2009,
#   'emissions': {'CO2': 8372.4,
#    'HFCs': 221.84,
#    'CH4': 921.27,
#    'N2O': 356.51,
#    'SF6': 0.16}},
#  {'country_id': 'CYP',
#   'year': 2010,
#   'emissions': {'CO2': 8004.91,
#    'HFCs': 246.34,
#    'CH4': 943.42,
#    'N2O': 376.83,
#    'SF6': 0.15}},
#  {'country_id': 'CYP',
#   'year': 2011,
#   'emissions': {'CO2': 7696.67,
#    'HFCs': 274.7,
#    'CH4': 962.21,
#    'N2O': 362.43,
#    'SF6': 0.15}},
#  {'country_id': 'CYP',
#   'year': 2012,
#   'emissions': {'CO2': 7160.97,
#    'HFCs': 315.74,
#    'CH4': 937.2,
#    'N2O': 355.29,
#    'SF6': 0.16}},
#  {'country_id': 'CYP',
#   'year': 2013,
#   'emissions': {'CO2': 6449.61,
#    'HFCs': 324.7,
#    'CH4': 918.04,
#    'N2O': 327.6,
#    'SF6': 0.15}},
#  {'country_id': 'CYP',
#   'year': 2014,
#   'emissions': {'CO2': 6878.56,
#    'HFCs': 320.54,
#    'CH4': 923.96,
#    'N2O': 330.57,
#    'SF6': 0.15}},
#  {'country_id': 'CZE',
#   'year': 1990,
#   'emissions': {'CO2': 161662.02,
#    'CH4': 23315.05,
#    'N2O': 11446.65,
#    'SF6': 85.22}},
#  {'country_id': 'CZE',
#   'year': 1991,
#   'emissions': {'CO2': 146047.34,
#    'CH4': 21607.18,
#    'N2O': 9898.54,
#    'SF6': 85.05}},
#  {'country_id': 'CZE',
#   'year': 1992,
#   'emissions': {'CO2': 141565.72,
#    'CH4': 20139.16,
#    'N2O': 8999.67,
#    'SF6': 86.35}},
#  {'country_id': 'CZE',
#   'year': 1993,
#   'emissions': {'CO2': 135588.57,
#    'CH4': 19226.59,
#    'N2O': 8064.59,
#    'SF6': 87.55}},
#  {'country_id': 'CZE',
#   'year': 1994,
#   'emissions': {'CO2': 129188.73,
#    'CH4': 18086.83,
#    'N2O': 7840.7,
#    'SF6': 88.64}},
#  {'country_id': 'CZE',
#   'year': 1995,
#   'emissions': {'CO2': 129767.17,
#    'HFCs': 0.23,
#    'CH4': 17744.94,
#    'N2O': 8027.72,
#    'PFCs': 0.01,
#    'SF6': 89.65}},
#  {'country_id': 'CZE',
#   'year': 1996,
#   'emissions': {'CO2': 132234.07,
#    'HFCs': 34.68,
#    'CH4': 17564.91,
#    'N2O': 7869.55,
#    'PFCs': 0.47,
#    'SF6': 99.24}},
#  {'country_id': 'CZE',
#   'year': 1997,
#   'emissions': {'CO2': 128732.64,
#    'HFCs': 99.02,
#    'CH4': 17105.08,
#    'N2O': 7838.49,
#    'PFCs': 1.56,
#    'SF6': 97.02}},
#  {'country_id': 'CZE',
#   'year': 1998,
#   'emissions': {'CO2': 123696.52,
#    'HFCs': 134.15,
#    'CH4': 16431.88,
#    'N2O': 7694.96,
#    'PFCs': 1.53,
#    'SF6': 95.75}},
#  {'country_id': 'CZE',
#   'year': 1999,
#   'emissions': {'CO2': 115475.26,
#    'HFCs': 147.6,
#    'CH4': 15771.02,
#    'N2O': 7561.35,
#    'PFCs': 0.84,
#    'SF6': 96.69}},
#  {'country_id': 'CZE',
#   'year': 2000,
#   'emissions': {'CO2': 125841.97,
#    'HFCs': 203.99,
#    'CH4': 14896.96,
#    'N2O': 7568.75,
#    'PFCs': 3.95,
#    'SF6': 109.13}},
#  {'country_id': 'CZE',
#   'year': 2001,
#   'emissions': {'CO2': 125541.54,
#    'HFCs': 308.59,
#    'CH4': 14582.7,
#    'N2O': 7650.74,
#    'PFCs': 8.54,
#    'SF6': 99.54}},
#  {'country_id': 'CZE',
#   'year': 2002,
#   'emissions': {'CO2': 122593.4,
#    'HFCs': 400.58,
#    'CH4': 14091.92,
#    'N2O': 7375.06,
#    'PFCs': 15.43,
#    'SF6': 121.95}},
#  {'country_id': 'CZE',
#   'year': 2003,
#   'emissions': {'CO2': 126151.65,
#    'HFCs': 508.64,
#    'CH4': 14100.16,
#    'N2O': 7044.6,
#    'PFCs': 7.27,
#    'SF6': 145.35}},
#  {'country_id': 'CZE',
#   'year': 2004,
#   'emissions': {'CO2': 126876.92,
#    'HFCs': 602.47,
#    'CH4': 13662.73,
#    'N2O': 7491.19,
#    'PFCs': 10.98,
#    'SF6': 121.16}},
#  {'country_id': 'CZE',
#   'year': 2005,
#   'emissions': {'CO2': 124590.14,
#    'HFCs': 700.77,
#    'CH4': 14032.83,
#    'N2O': 7107.64,
#    'PFCs': 12.74,
#    'SF6': 112.32}},
#  {'country_id': 'CZE',
#   'year': 2006,
#   'emissions': {'CO2': 125923.4,
#    'HFCs': 937.23,
#    'CH4': 14265.96,
#    'N2O': 7069.14,
#    'PFCs': 29.01,
#    'SF6': 109.41}},
#  {'country_id': 'CZE',
#   'year': 2007,
#   'emissions': {'CO2': 126933.16,
#    'HFCs': 1282.34,
#    'CH4': 13800.57,
#    'N2O': 7067.66,
#    'PFCs': 27.03,
#    'SF6': 94.53}},
#  {'country_id': 'CZE',
#   'year': 2008,
#   'emissions': {'CO2': 121780.72,
#    'HFCs': 1511.87,
#    'CH4': 14227.76,
#    'N2O': 6930.08,
#    'PFCs': 37.29,
#    'SF6': 94.4}},
#  {'country_id': 'CZE',
#   'year': 2009,
#   'emissions': {'CO2': 113970.03,
#    'HFCs': 1639.13,
#    'CH4': 13800.63,
#    'N2O': 6616.85,
#    'PFCs': 44.14,
#    'SF6': 97.15}},
#  {'country_id': 'CZE',
#   'year': 2010,
#   'emissions': {'CO2': 115757.37,
#    'HFCs': 1947.71,
#    'CH4': 13992.58,
#    'N2O': 6398.16,
#    'PFCs': 49.32,
#    'SF6': 81.29}},
#  {'country_id': 'CZE',
#   'year': 2011,
#   'emissions': {'CO2': 114113.15,
#    'HFCs': 2219.11,
#    'CH4': 14017.04,
#    'N2O': 6557.25,
#    'PFCs': 10.72,
#    'SF6': 86.43}},
#  {'country_id': 'CZE',
#   'year': 2012,
#   'emissions': {'CO2': 109841.33,
#    'HFCs': 2395.39,
#    'CH4': 14086.09,
#    'NF3': 1.8,
#    'N2O': 6441.22,
#    'PFCs': 8.74,
#    'SF6': 90.68}},
#  {'country_id': 'CZE',
#   'year': 2013,
#   'emissions': {'CO2': 106477.09,
#    'HFCs': 2621.18,
#    'CH4': 13435.26,
#    'NF3': 3.82,
#    'N2O': 6335.43,
#    'PFCs': 6.61,
#    'SF6': 93.38}},
#  {'country_id': 'CZE',
#   'year': 2014,
#   'emissions': {'CO2': 101159.12,
#    'HFCs': 2830.38,
#    'CH4': 13491.74,
#    'NF3': 2.35,
#    'N2O': 6660.69,
#    'PFCs': 5.34,
#    'SF6': 96.01}},
#  {'country_id': 'DEU',
#   'year': 1990,
#   'emissions': {'CO2': 1052238.23,
#    'HFCs': 50.32,
#    'CH4': 119234.77,
#    'NF3': 6.88,
#    'N2O': 65188.85,
#    'PFCs': 3060.23,
#    'SF6': 4343.64}},
#  {'country_id': 'DEU',
#   'year': 1991,
#   'emissions': {'CO2': 1014119.72,
#    'HFCs': 45.92,
#    'CH4': 113697.66,
#    'NF3': 6.88,
#    'N2O': 62711.85,
#    'PFCs': 2654.62,
#    'SF6': 4745.88}},
#  {'country_id': 'DEU',
#   'year': 1992,
#   'emissions': {'CO2': 965790.84,
#    'HFCs': 287.56,
#    'CH4': 110261.12,
#    'NF3': 6.88,
#    'N2O': 63686.85,
#    'PFCs': 2407.12,
#    'SF6': 5237.81}},
#  {'country_id': 'DEU',
#   'year': 1993,
#   'emissions': {'CO2': 955977.6,
#    'HFCs': 2492.86,
#    'CH4': 110830.33,
#    'NF3': 6.88,
#    'N2O': 60921.62,
#    'PFCs': 2256.39,
#    'SF6': 5973.59}},
#  {'country_id': 'DEU',
#   'year': 1994,
#   'emissions': {'CO2': 939207.33,
#    'HFCs': 2683.1,
#    'CH4': 106948.2,
#    'NF3': 6.88,
#    'N2O': 61756.64,
#    'PFCs': 1918.78,
#    'SF6': 6249.23}},
#  {'country_id': 'DEU',
#   'year': 1995,
#   'emissions': {'CO2': 938148.09,
#    'HFCs': 2606.07,
#    'CH4': 104722.35,
#    'NF3': 5.29,
#    'N2O': 61135.98,
#    'PFCs': 2085.72,
#    'SF6': 6467.15}},
#  {'country_id': 'DEU',
#   'year': 1996,
#   'emissions': {'CO2': 958368.72,
#    'HFCs': 3392.98,
#    'CH4': 102065.9,
#    'NF3': 7.22,
#    'N2O': 62404.53,
#    'PFCs': 2041.19,
#    'SF6': 6162.49}},
#  {'country_id': 'DEU',
#   'year': 1997,
#   'emissions': {'CO2': 930768.56,
#    'HFCs': 4134.2,
#    'CH4': 97821.41,
#    'NF3': 7.85,
#    'N2O': 59540.8,
#    'PFCs': 1653.48,
#    'SF6': 6108.84}},
#  {'country_id': 'DEU',
#   'year': 1998,
#   'emissions': {'CO2': 922778.54,
#    'HFCs': 4837.33,
#    'CH4': 92582.83,
#    'NF3': 7.58,
#    'N2O': 46658.05,
#    'PFCs': 1781.79,
#    'SF6': 5888.91}},
#  {'country_id': 'DEU',
#   'year': 1999,
#   'emissions': {'CO2': 895336.79,
#    'HFCs': 5161.16,
#    'CH4': 91950.88,
#    'NF3': 6.69,
#    'N2O': 43242.49,
#    'PFCs': 1484.77,
#    'SF6': 4289.75}},
#  {'country_id': 'DEU',
#   'year': 2000,
#   'emissions': {'CO2': 899284.99,
#    'HFCs': 5972.05,
#    'CH4': 87647.83,
#    'NF3': 8.92,
#    'N2O': 43274.08,
#    'PFCs': 956.32,
#    'SF6': 4072.5}},
#  {'country_id': 'DEU',
#   'year': 2001,
#   'emissions': {'CO2': 915634.44,
#    'HFCs': 7346.29,
#    'CH4': 83997.31,
#    'NF3': 7.82,
#    'N2O': 44665.52,
#    'PFCs': 869.6,
#    'SF6': 3751.78}},
#  {'country_id': 'DEU',
#   'year': 2002,
#   'emissions': {'CO2': 899161.57,
#    'HFCs': 7943.21,
#    'CH4': 80070.72,
#    'NF3': 12.22,
#    'N2O': 43849.57,
#    'PFCs': 945.65,
#    'SF6': 3087.04}},
#  {'country_id': 'DEU',
#   'year': 2003,
#   'emissions': {'CO2': 900377.59,
#    'HFCs': 8102.16,
#    'CH4': 76675.51,
#    'NF3': 19.38,
#    'N2O': 43482.07,
#    'PFCs': 1015.53,
#    'SF6': 3034.16}},
#  {'country_id': 'DEU',
#   'year': 2004,
#   'emissions': {'CO2': 886344.63,
#    'HFCs': 8546.58,
#    'CH4': 71621.03,
#    'NF3': 22.81,
#    'N2O': 45657.66,
#    'PFCs': 977.4,
#    'SF6': 3243.55}},
#  {'country_id': 'DEU',
#   'year': 2005,
#   'emissions': {'CO2': 865958.51,
#    'HFCs': 8752.63,
#    'CH4': 68393.12,
#    'NF3': 34.49,
#    'N2O': 43642.29,
#    'PFCs': 836.77,
#    'SF6': 3319.87}},
#  {'country_id': 'DEU',
#   'year': 2006,
#   'emissions': {'CO2': 877422.46,
#    'HFCs': 9135.86,
#    'CH4': 64446.01,
#    'NF3': 27.84,
#    'N2O': 43351.06,
#    'PFCs': 668.47,
#    'SF6': 3241.5}},
#  {'country_id': 'DEU',
#   'year': 2007,
#   'emissions': {'CO2': 850795.72,
#    'HFCs': 9422.42,
#    'CH4': 62176.44,
#    'NF3': 12.02,
#    'N2O': 45257.89,
#    'PFCs': 587.34,
#    'SF6': 3180.59}},
#  {'country_id': 'DEU',
#   'year': 2008,
#   'emissions': {'CO2': 853229.94,
#    'HFCs': 9368.03,
#    'CH4': 61206.59,
#    'NF3': 29.6,
#    'N2O': 45768.64,
#    'PFCs': 566.0,
#    'SF6': 2971.21}},
#  {'country_id': 'DEU',
#   'year': 2009,
#   'emissions': {'CO2': 788422.44,
#    'HFCs': 9613.58,
#    'CH4': 58947.98,
#    'NF3': 29.08,
#    'N2O': 44969.99,
#    'PFCs': 405.9,
#    'SF6': 2923.98}},
#  {'country_id': 'DEU',
#   'year': 2010,
#   'emissions': {'CO2': 832259.2,
#    'HFCs': 9914.69,
#    'CH4': 58092.17,
#    'NF3': 61.43,
#    'N2O': 36952.51,
#    'PFCs': 345.37,
#    'SF6': 3047.04}},
#  {'country_id': 'DEU',
#   'year': 2011,
#   'emissions': {'CO2': 812483.22,
#    'HFCs': 10353.26,
#    'CH4': 56966.47,
#    'NF3': 61.21,
#    'N2O': 38347.32,
#    'PFCs': 278.51,
#    'SF6': 3163.07}},
#  {'country_id': 'DEU',
#   'year': 2012,
#   'emissions': {'CO2': 817031.44,
#    'HFCs': 10547.63,
#    'CH4': 57647.41,
#    'NF3': 35.21,
#    'N2O': 37497.49,
#    'PFCs': 242.2,
#    'SF6': 3154.89}},
#  {'country_id': 'DEU',
#   'year': 2013,
#   'emissions': {'CO2': 835792.63,
#    'HFCs': 10569.43,
#    'CH4': 56975.08,
#    'NF3': 16.03,
#    'N2O': 38084.92,
#    'PFCs': 258.24,
#    'SF6': 3261.2}},
#  {'country_id': 'DEU',
#   'year': 2014,
#   'emissions': {'CO2': 792902.79,
#    'HFCs': 10750.37,
#    'CH4': 55527.86,
#    'NF3': 20.28,
#    'N2O': 38780.29,
#    'PFCs': 234.23,
#    'SF6': 3396.17}},
#  {'country_id': 'DNK',
#   'year': 1990,
#   'emissions': {'CO2': 54306.43,
#    'CH4': 8082.71,
#    'N2O': 7813.98,
#    'SF6': 42.41}},
#  {'country_id': 'DNK',
#   'year': 1991,
#   'emissions': {'CO2': 64874.81, 'CH4': 8279.66, 'N2O': 7680.7, 'SF6': 60.58}},
#  {'country_id': 'DNK',
#   'year': 1992,
#   'emissions': {'CO2': 58960.31,
#    'HFCs': 3.69,
#    'CH4': 8364.65,
#    'N2O': 7610.88,
#    'SF6': 85.16}},
#  {'country_id': 'DNK',
#   'year': 1993,
#   'emissions': {'CO2': 61038.67,
#    'HFCs': 102.29,
#    'CH4': 8570.92,
#    'N2O': 7117.56,
#    'SF6': 96.64}},
#  {'country_id': 'DNK',
#   'year': 1994,
#   'emissions': {'CO2': 64988.78,
#    'HFCs': 146.36,
#    'CH4': 8437.69,
#    'N2O': 7207.6,
#    'PFCs': 0.07,
#    'SF6': 116.58}},
#  {'country_id': 'DNK',
#   'year': 1995,
#   'emissions': {'CO2': 61914.16,
#    'HFCs': 241.48,
#    'CH4': 8497.61,
#    'N2O': 7085.35,
#    'PFCs': 0.63,
#    'SF6': 102.58}},
#  {'country_id': 'DNK',
#   'year': 1996,
#   'emissions': {'CO2': 75110.84,
#    'HFCs': 379.98,
#    'CH4': 8608.32,
#    'N2O': 6666.75,
#    'PFCs': 2.09,
#    'SF6': 58.31}},
#  {'country_id': 'DNK',
#   'year': 1997,
#   'emissions': {'CO2': 65457.83,
#    'HFCs': 377.53,
#    'CH4': 8506.8,
#    'N2O': 6794.52,
#    'PFCs': 5.2,
#    'SF6': 69.87}},
#  {'country_id': 'DNK',
#   'year': 1998,
#   'emissions': {'CO2': 61117.34,
#    'HFCs': 477.68,
#    'CH4': 8572.25,
#    'N2O': 6789.73,
#    'PFCs': 11.47,
#    'SF6': 56.87}},
#  {'country_id': 'DNK',
#   'year': 1999,
#   'emissions': {'CO2': 58456.42,
#    'HFCs': 587.21,
#    'CH4': 8465.65,
#    'N2O': 6992.44,
#    'PFCs': 15.74,
#    'SF6': 62.01}},
#  {'country_id': 'DNK',
#   'year': 2000,
#   'emissions': {'CO2': 54148.9,
#    'HFCs': 710.67,
#    'CH4': 8355.11,
#    'N2O': 6837.49,
#    'PFCs': 22.57,
#    'SF6': 56.15}},
#  {'country_id': 'DNK',
#   'year': 2001,
#   'emissions': {'CO2': 55845.15,
#    'HFCs': 747.11,
#    'CH4': 8611.92,
#    'N2O': 6645.02,
#    'PFCs': 27.91,
#    'SF6': 28.2}},
#  {'country_id': 'DNK',
#   'year': 2002,
#   'emissions': {'CO2': 55339.67,
#    'HFCs': 794.62,
#    'CH4': 8534.71,
#    'N2O': 6726.27,
#    'PFCs': 28.01,
#    'SF6': 23.53}},
#  {'country_id': 'DNK',
#   'year': 2003,
#   'emissions': {'CO2': 60493.96,
#    'HFCs': 829.37,
#    'CH4': 8547.45,
#    'N2O': 6490.23,
#    'PFCs': 24.59,
#    'SF6': 29.59}},
#  {'country_id': 'DNK',
#   'year': 2004,
#   'emissions': {'CO2': 54916.91,
#    'HFCs': 894.75,
#    'CH4': 8392.88,
#    'N2O': 6050.83,
#    'PFCs': 20.53,
#    'SF6': 30.94}},
#  {'country_id': 'DNK',
#   'year': 2005,
#   'emissions': {'CO2': 51307.24,
#    'HFCs': 951.91,
#    'CH4': 8148.67,
#    'N2O': 5411.65,
#    'PFCs': 18.77,
#    'SF6': 20.05}},
#  {'country_id': 'DNK',
#   'year': 2006,
#   'emissions': {'CO2': 59162.5,
#    'HFCs': 977.63,
#    'CH4': 8038.4,
#    'N2O': 5389.36,
#    'PFCs': 21.15,
#    'SF6': 33.62}},
#  {'country_id': 'DNK',
#   'year': 2007,
#   'emissions': {'CO2': 54429.09,
#    'HFCs': 1010.2,
#    'CH4': 8033.12,
#    'N2O': 5482.21,
#    'PFCs': 21.19,
#    'SF6': 28.24}},
#  {'country_id': 'DNK',
#   'year': 2008,
#   'emissions': {'CO2': 50935.67,
#    'HFCs': 1014.58,
#    'CH4': 7888.33,
#    'N2O': 5449.49,
#    'PFCs': 18.44,
#    'SF6': 29.46}},
#  {'country_id': 'DNK',
#   'year': 2009,
#   'emissions': {'CO2': 48592.21,
#    'HFCs': 964.77,
#    'CH4': 7736.95,
#    'N2O': 5148.0,
#    'PFCs': 19.98,
#    'SF6': 34.37}},
#  {'country_id': 'DNK',
#   'year': 2010,
#   'emissions': {'CO2': 48993.42,
#    'HFCs': 971.91,
#    'CH4': 7786.92,
#    'N2O': 5137.16,
#    'PFCs': 18.67,
#    'SF6': 35.93}},
#  {'country_id': 'DNK',
#   'year': 2011,
#   'emissions': {'CO2': 43970.79,
#    'HFCs': 908.39,
#    'CH4': 7642.0,
#    'N2O': 5133.77,
#    'PFCs': 15.76,
#    'SF6': 69.54}},
#  {'country_id': 'DNK',
#   'year': 2012,
#   'emissions': {'CO2': 39524.4,
#    'HFCs': 826.14,
#    'CH4': 7484.7,
#    'N2O': 4974.3,
#    'PFCs': 12.25,
#    'SF6': 112.18}},
#  {'country_id': 'DNK',
#   'year': 2013,
#   'emissions': {'CO2': 41537.04,
#    'HFCs': 810.64,
#    'CH4': 7380.67,
#    'N2O': 5114.31,
#    'PFCs': 10.9,
#    'SF6': 130.79}},
#  {'country_id': 'DNK',
#   'year': 2014,
#   'emissions': {'CO2': 37460.66,
#    'HFCs': 735.44,
#    'CH4': 7362.97,
#    'N2O': 5084.61,
#    'PFCs': 8.66,
#    'SF6': 132.96}},
#  {'country_id': 'ESP',
#   'year': 1990,
#   'emissions': {'CO2': 230154.96,
#    'HFCs': 3039.92,
#    'CH4': 29575.35,
#    'N2O': 16602.66,
#    'PFCs': 1164.38,
#    'SF6': 63.61}},
#  {'country_id': 'ESP',
#   'year': 1991,
#   'emissions': {'CO2': 239725.18,
#    'HFCs': 2756.35,
#    'CH4': 29619.81,
#    'N2O': 16218.46,
#    'PFCs': 1087.13,
#    'SF6': 69.71}},
#  {'country_id': 'ESP',
#   'year': 1992,
#   'emissions': {'CO2': 248407.16,
#    'HFCs': 3494.58,
#    'CH4': 30128.94,
#    'N2O': 15529.66,
#    'PFCs': 1026.32,
#    'SF6': 72.94}},
#  {'country_id': 'ESP',
#   'year': 1993,
#   'emissions': {'CO2': 239938.29,
#    'HFCs': 2856.56,
#    'CH4': 30056.57,
#    'N2O': 14526.19,
#    'PFCs': 1065.88,
#    'SF6': 77.02}},
#  {'country_id': 'ESP',
#   'year': 1994,
#   'emissions': {'CO2': 252389.35,
#    'HFCs': 4373.88,
#    'CH4': 30913.13,
#    'N2O': 16044.96,
#    'PFCs': 1038.45,
#    'SF6': 84.65}},
#  {'country_id': 'ESP',
#   'year': 1995,
#   'emissions': {'CO2': 265725.35,
#    'HFCs': 5872.42,
#    'CH4': 31370.41,
#    'N2O': 16057.08,
#    'PFCs': 1055.37,
#    'SF6': 100.93}},
#  {'country_id': 'ESP',
#   'year': 1996,
#   'emissions': {'CO2': 253708.87,
#    'HFCs': 6546.41,
#    'CH4': 32667.37,
#    'N2O': 17900.42,
#    'PFCs': 1002.13,
#    'SF6': 111.43}},
#  {'country_id': 'ESP',
#   'year': 1997,
#   'emissions': {'CO2': 266391.93,
#    'HFCs': 7722.72,
#    'CH4': 33553.52,
#    'N2O': 17415.77,
#    'PFCs': 1025.74,
#    'SF6': 152.53}},
#  {'country_id': 'ESP',
#   'year': 1998,
#   'emissions': {'CO2': 274911.1,
#    'HFCs': 7771.82,
#    'CH4': 34044.21,
#    'N2O': 18135.41,
#    'PFCs': 943.53,
#    'SF6': 158.12}},
#  {'country_id': 'ESP',
#   'year': 1999,
#   'emissions': {'CO2': 298531.03,
#    'HFCs': 9815.81,
#    'CH4': 34269.92,
#    'N2O': 18949.32,
#    'PFCs': 856.92,
#    'SF6': 167.98}},
#  {'country_id': 'ESP',
#   'year': 2000,
#   'emissions': {'CO2': 311599.72,
#    'HFCs': 11430.35,
#    'CH4': 35247.71,
#    'N2O': 19684.73,
#    'PFCs': 496.12,
#    'SF6': 187.68}},
#  {'country_id': 'ESP',
#   'year': 2001,
#   'emissions': {'CO2': 312395.4,
#    'HFCs': 8120.98,
#    'CH4': 36310.63,
#    'N2O': 18524.95,
#    'PFCs': 274.56,
#    'SF6': 163.18}},
#  {'country_id': 'ESP',
#   'year': 2002,
#   'emissions': {'CO2': 332200.84,
#    'HFCs': 6739.28,
#    'CH4': 36482.14,
#    'N2O': 17941.18,
#    'PFCs': 282.23,
#    'SF6': 180.41}},
#  {'country_id': 'ESP',
#   'year': 2003,
#   'emissions': {'CO2': 336672.42,
#    'HFCs': 8535.7,
#    'CH4': 36826.72,
#    'N2O': 18787.92,
#    'PFCs': 270.26,
#    'SF6': 176.33}},
#  {'country_id': 'ESP',
#   'year': 2004,
#   'emissions': {'CO2': 353472.61,
#    'HFCs': 8863.41,
#    'CH4': 36137.97,
#    'N2O': 17983.47,
#    'PFCs': 261.64,
#    'SF6': 199.78}},
# ...
#   'emissions': {'CO2': 53447.44,
#    'CH4': 6887.86,
#    'N2O': 3999.47,
#    'PFCs': 309.73,
#    'SF6': 0.04}},
#  {'country_id': 'SVK',
#   'year': 1992,
#   'emissions': {'CO2': 48979.13,
#    'CH4': 6553.88,
#    'N2O': 3383.0,
#    'PFCs': 288.24,
#    'SF6': 0.04}},
#  {'country_id': 'SVK',
#   'year': 1993,
#   'emissions': {'CO2': 46467.55,
#    'CH4': 6155.27,
#    'N2O': 2886.05,
#    'PFCs': 180.32,
#    'SF6': 0.09}},
#  {'country_id': 'SVK',
#   'year': 1994,
#   'emissions': {'CO2': 43638.49,
#    'HFCs': 0.2,
#    'CH4': 5988.54,
#    'N2O': 3255.22,
#    'PFCs': 153.23,
#    'SF6': 17.62}},
#  {'country_id': 'SVK',
#   'year': 1995,
#   'emissions': {'CO2': 44679.54,
#    'HFCs': 10.49,
#    'CH4': 6132.91,
#    'N2O': 3439.84,
#    'PFCs': 132.65,
#    'SF6': 10.15}},
#  {'country_id': 'SVK',
#   'year': 1996,
#   'emissions': {'CO2': 44978.91,
#    'HFCs': 22.23,
#    'CH4': 6049.61,
#    'N2O': 3603.42,
#    'PFCs': 40.72,
#    'SF6': 11.16}},
#  {'country_id': 'SVK',
#   'year': 1997,
#   'emissions': {'CO2': 45040.27,
#    'HFCs': 32.39,
#    'CH4': 5749.46,
#    'N2O': 3523.2,
#    'PFCs': 40.16,
#    'SF6': 11.47}},
#  {'country_id': 'SVK',
#   'year': 1998,
#   'emissions': {'CO2': 44016.99,
#    'HFCs': 42.62,
#    'CH4': 5708.47,
#    'N2O': 3184.02,
#    'PFCs': 29.1,
#    'SF6': 12.65}},
#  {'country_id': 'SVK',
#   'year': 1999,
#   'emissions': {'CO2': 43181.31,
#    'HFCs': 61.63,
#    'CH4': 5657.97,
#    'N2O': 2770.59,
#    'PFCs': 16.27,
#    'SF6': 12.64}},
#  {'country_id': 'SVK',
#   'year': 2000,
#   'emissions': {'CO2': 41155.01,
#    'HFCs': 84.73,
#    'CH4': 5422.74,
#    'N2O': 3022.05,
#    'PFCs': 14.91,
#    'SF6': 13.04}},
#  {'country_id': 'SVK',
#   'year': 2001,
#   'emissions': {'CO2': 43468.09,
#    'HFCs': 112.83,
#    'CH4': 5358.11,
#    'N2O': 3159.28,
#    'PFCs': 16.02,
#    'SF6': 13.33}},
#  {'country_id': 'SVK',
#   'year': 2002,
#   'emissions': {'CO2': 41593.53,
#    'HFCs': 146.23,
#    'CH4': 5237.54,
#    'N2O': 3135.49,
#    'PFCs': 17.18,
#    'SF6': 14.78}},
#  {'country_id': 'SVK',
#   'year': 2003,
#   'emissions': {'CO2': 42060.55,
#    'HFCs': 175.02,
#    'CH4': 5138.51,
#    'N2O': 3170.99,
#    'PFCs': 26.45,
#    'SF6': 15.06}},
#  {'country_id': 'SVK',
#   'year': 2004,
#   'emissions': {'CO2': 42576.96,
#    'HFCs': 208.94,
#    'CH4': 5183.93,
#    'N2O': 3306.27,
#    'PFCs': 23.63,
#    'SF6': 15.43}},
#  {'country_id': 'SVK',
#   'year': 2005,
#   'emissions': {'CO2': 42581.02,
#    'HFCs': 240.67,
#    'CH4': 5184.37,
#    'N2O': 3240.77,
#    'PFCs': 24.16,
#    'SF6': 16.38}},
#  {'country_id': 'SVK',
#   'year': 2006,
#   'emissions': {'CO2': 42320.48,
#    'HFCs': 282.67,
#    'CH4': 5028.69,
#    'N2O': 3515.89,
#    'PFCs': 42.47,
#    'SF6': 16.71}},
#  {'country_id': 'SVK',
#   'year': 2007,
#   'emissions': {'CO2': 40725.3,
#    'HFCs': 325.44,
#    'CH4': 4894.01,
#    'N2O': 3413.5,
#    'PFCs': 29.42,
#    'SF6': 17.39}},
#  {'country_id': 'SVK',
#   'year': 2008,
#   'emissions': {'CO2': 41236.32,
#    'HFCs': 386.23,
#    'CH4': 5120.16,
#    'N2O': 3284.42,
#    'PFCs': 42.76,
#    'SF6': 18.85}},
#  {'country_id': 'SVK',
#   'year': 2009,
#   'emissions': {'CO2': 37433.43,
#    'HFCs': 441.63,
#    'CH4': 4668.55,
#    'N2O': 2973.51,
#    'PFCs': 21.0,
#    'SF6': 19.51}},
#  {'country_id': 'SVK',
#   'year': 2010,
#   'emissions': {'CO2': 38385.94,
#    'HFCs': 529.68,
#    'CH4': 4707.52,
#    'N2O': 2815.09,
#    'PFCs': 25.01,
#    'SF6': 19.62}},
#  {'country_id': 'SVK',
#   'year': 2011,
#   'emissions': {'CO2': 37880.85,
#    'HFCs': 521.86,
#    'CH4': 4788.51,
#    'N2O': 2371.89,
#    'PFCs': 20.11,
#    'SF6': 20.8}},
#  {'country_id': 'SVK',
#   'year': 2012,
#   'emissions': {'CO2': 35867.9,
#    'HFCs': 530.05,
#    'CH4': 4408.5,
#    'N2O': 2322.24,
#    'PFCs': 25.66,
#    'SF6': 21.24}},
#  {'country_id': 'SVK',
#   'year': 2013,
#   'emissions': {'CO2': 35395.15,
#    'HFCs': 535.19,
#    'CH4': 4555.87,
#    'N2O': 2274.15,
#    'PFCs': 9.81,
#    'SF6': 22.3}},
#  {'country_id': 'SVK',
#   'year': 2014,
#   'emissions': {'CO2': 33387.43,
#    'HFCs': 546.02,
#    'CH4': 4363.29,
#    'N2O': 2335.55,
#    'PFCs': 11.15,
#    'SF6': 14.17}},
#  {'country_id': 'SVN',
#   'year': 1990,
#   'emissions': {'CO2': 15088.31,
#    'CH4': 2471.36,
#    'N2O': 839.36,
#    'PFCs': 207.59,
#    'SF6': 9.83}},
#  {'country_id': 'SVN',
#   'year': 1991,
#   'emissions': {'CO2': 14007.28,
#    'CH4': 2384.37,
#    'N2O': 780.83,
#    'PFCs': 129.4,
#    'SF6': 9.64}},
#  {'country_id': 'SVN',
#   'year': 1992,
#   'emissions': {'CO2': 14009.4,
#    'CH4': 2429.88,
#    'N2O': 832.94,
#    'PFCs': 128.18,
#    'SF6': 9.67}},
#  {'country_id': 'SVN',
#   'year': 1993,
#   'emissions': {'CO2': 14303.99,
#    'CH4': 2353.83,
#    'N2O': 808.92,
#    'PFCs': 128.25,
#    'SF6': 10.54}},
#  {'country_id': 'SVN',
#   'year': 1994,
#   'emissions': {'CO2': 14648.73,
#    'CH4': 2350.49,
#    'N2O': 866.21,
#    'PFCs': 128.18,
#    'SF6': 10.84}},
#  {'country_id': 'SVN',
#   'year': 1995,
#   'emissions': {'CO2': 15277.74,
#    'HFCs': 35.83,
#    'CH4': 2378.69,
#    'N2O': 928.48,
#    'PFCs': 128.14,
#    'SF6': 12.13}},
#  {'country_id': 'SVN',
#   'year': 1996,
#   'emissions': {'CO2': 15945.18,
#    'HFCs': 34.8,
#    'CH4': 2338.37,
#    'N2O': 981.35,
#    'PFCs': 127.67,
#    'SF6': 12.88}},
#  {'country_id': 'SVN',
#   'year': 1997,
#   'emissions': {'CO2': 16275.56,
#    'HFCs': 41.33,
#    'CH4': 2331.42,
#    'N2O': 1004.71,
#    'PFCs': 128.19,
#    'SF6': 13.25}},
#  {'country_id': 'SVN',
#   'year': 1998,
#   'emissions': {'CO2': 15980.48,
#    'HFCs': 37.69,
#    'CH4': 2370.5,
#    'N2O': 990.86,
#    'PFCs': 128.08,
#    'SF6': 12.77}},
#  {'country_id': 'SVN',
#   'year': 1999,
#   'emissions': {'CO2': 15353.07,
#    'HFCs': 36.74,
#    'CH4': 2373.46,
#    'N2O': 985.87,
#    'PFCs': 128.29,
#    'SF6': 15.36}},
#  {'country_id': 'SVN',
#   'year': 2000,
#   'emissions': {'CO2': 15460.15,
#    'HFCs': 50.04,
#    'CH4': 2459.13,
#    'N2O': 1012.15,
#    'PFCs': 129.75,
#    'SF6': 15.01}},
#  {'country_id': 'SVN',
#   'year': 2001,
#   'emissions': {'CO2': 16384.76,
#    'HFCs': 62.46,
#    'CH4': 2422.02,
#    'N2O': 996.86,
#    'PFCs': 129.26,
#    'SF6': 15.37}},
#  {'country_id': 'SVN',
#   'year': 2002,
#   'emissions': {'CO2': 16526.31,
#    'HFCs': 78.61,
#    'CH4': 2515.79,
#    'N2O': 887.58,
#    'PFCs': 135.07,
#    'SF6': 16.54}},
#  {'country_id': 'SVN',
#   'year': 2003,
#   'emissions': {'CO2': 16289.39,
#    'HFCs': 107.95,
#    'CH4': 2471.37,
#    'N2O': 853.01,
#    'PFCs': 139.44,
#    'SF6': 17.09}},
#  {'country_id': 'SVN',
#   'year': 2004,
#   'emissions': {'CO2': 16639.17,
#    'HFCs': 130.2,
#    'CH4': 2449.21,
#    'N2O': 821.7,
#    'PFCs': 140.69,
#    'SF6': 17.47}},
#  {'country_id': 'SVN',
#   'year': 2005,
#   'emissions': {'CO2': 16938.32,
#    'HFCs': 156.15,
#    'CH4': 2437.58,
#    'N2O': 830.56,
#    'PFCs': 142.13,
#    'SF6': 18.0}},
#  {'country_id': 'SVN',
#   'year': 2006,
#   'emissions': {'CO2': 17129.8,
#    'HFCs': 184.28,
#    'CH4': 2391.74,
#    'N2O': 836.96,
#    'PFCs': 134.26,
#    'SF6': 17.93}},
#  {'country_id': 'SVN',
#   'year': 2007,
#   'emissions': {'CO2': 17272.38,
#    'HFCs': 210.77,
#    'CH4': 2391.91,
#    'N2O': 839.31,
#    'PFCs': 99.68,
#    'SF6': 17.79}},
#  {'country_id': 'SVN',
#   'year': 2008,
#   'emissions': {'CO2': 18219.73,
#    'HFCs': 230.52,
#    'CH4': 2247.93,
#    'N2O': 793.1,
#    'PFCs': 14.74,
#    'SF6': 17.54}},
#  {'country_id': 'SVN',
#   'year': 2009,
#   'emissions': {'CO2': 16328.21,
#    'HFCs': 248.39,
#    'CH4': 2207.16,
#    'N2O': 789.16,
#    'PFCs': 5.24,
#    'SF6': 17.2}},
#  {'country_id': 'SVN',
#   'year': 2010,
#   'emissions': {'CO2': 16363.43,
#    'HFCs': 263.91,
#    'CH4': 2187.9,
#    'N2O': 775.92,
#    'PFCs': 9.64,
#    'SF6': 17.97}},
#  {'country_id': 'SVN',
#   'year': 2011,
#   'emissions': {'CO2': 16348.24,
#    'HFCs': 278.73,
#    'CH4': 2182.15,
#    'N2O': 779.05,
#    'PFCs': 20.16,
#    'SF6': 18.14}},
#  {'country_id': 'SVN',
#   'year': 2012,
#   'emissions': {'CO2': 15800.19,
#    'HFCs': 291.48,
#    'CH4': 2127.71,
#    'N2O': 781.0,
#    'PFCs': 18.11,
#    'SF6': 16.94}},
#  {'country_id': 'SVN',
#   'year': 2013,
#   'emissions': {'CO2': 15148.73,
#    'HFCs': 301.92,
#    'CH4': 2080.23,
#    'N2O': 751.64,
#    'PFCs': 15.31,
#    'SF6': 15.95}},
#  {'country_id': 'SVN',
#   'year': 2014,
#   'emissions': {'CO2': 13489.98,
#    'HFCs': 323.82,
#    'CH4': 1978.92,
#    'N2O': 758.84,
#    'PFCs': 15.22,
#    'SF6': 15.52}},
#  {'country_id': 'SWE',
#   'year': 1990,
#   'emissions': {'CO2': 57546.54,
#    'HFCs': 4.6,
#    'CH4': 7989.91,
#    'N2O': 5840.75,
#    'PFCs': 433.72,
#    'SF6': 101.73}},
#  {'country_id': 'SWE',
#   'year': 1991,
#   'emissions': {'CO2': 57755.63,
#    'HFCs': 9.36,
#    'CH4': 7989.38,
#    'N2O': 5746.49,
#    'PFCs': 437.69,
#    'SF6': 102.69}},
#  {'country_id': 'SWE',
#   'year': 1992,
#   'emissions': {'CO2': 57482.06,
#    'HFCs': 11.82,
#    'CH4': 8083.24,
#    'N2O': 5557.17,
#    'PFCs': 290.18,
#    'SF6': 102.58}},
#  {'country_id': 'SWE',
#   'year': 1993,
#   'emissions': {'CO2': 57425.95,
#    'HFCs': 38.43,
#    'CH4': 8078.74,
#    'N2O': 5830.19,
#    'PFCs': 334.54,
#    'SF6': 99.35}},
#  {'country_id': 'SWE',
#   'year': 1994,
#   'emissions': {'CO2': 59877.0,
#    'HFCs': 87.02,
#    'CH4': 7989.15,
#    'N2O': 5813.5,
#    'PFCs': 358.45,
#    'SF6': 106.37}},
#  {'country_id': 'SWE',
#   'year': 1995,
#   'emissions': {'CO2': 59318.67,
#    'HFCs': 149.18,
#    'CH4': 7882.65,
#    'N2O': 6148.13,
#    'PFCs': 395.55,
#    'SF6': 135.19}},
#  {'country_id': 'SWE',
#   'year': 1996,
#   'emissions': {'CO2': 63238.79,
#    'HFCs': 235.27,
#    'CH4': 7839.93,
#    'N2O': 5793.83,
#    'PFCs': 349.41,
#    'SF6': 116.88}},
#  {'country_id': 'SWE',
#   'year': 1997,
#   'emissions': {'CO2': 58154.53,
#    'HFCs': 352.79,
#    'CH4': 7776.31,
#    'N2O': 6006.2,
#    'PFCs': 322.87,
#    'SF6': 159.59}},
#  {'country_id': 'SWE',
#   'year': 1998,
#   'emissions': {'CO2': 58733.41,
#    'HFCs': 435.27,
#    'CH4': 7594.95,
#    'N2O': 5897.18,
#    'PFCs': 313.83,
#    'SF6': 111.22}},
#  {'country_id': 'SWE',
#   'year': 1999,
#   'emissions': {'CO2': 55861.22,
#    'HFCs': 549.65,
#    'CH4': 7404.1,
#    'N2O': 5909.75,
#    'PFCs': 335.77,
#    'SF6': 121.21}},
#  {'country_id': 'SWE',
#   'year': 2000,
#   'emissions': {'CO2': 54730.42,
#    'HFCs': 631.37,
#    'CH4': 7192.46,
#    'N2O': 5918.67,
#    'PFCs': 277.06,
#    'SF6': 118.78}},
#  {'country_id': 'SWE',
#   'year': 2001,
#   'emissions': {'CO2': 55686.75,
#    'HFCs': 683.19,
#    'CH4': 7126.72,
#    'N2O': 5301.23,
#    'PFCs': 271.45,
#    'SF6': 122.78}},
#  {'country_id': 'SWE',
#   'year': 2002,
#   'emissions': {'CO2': 56631.9,
#    'HFCs': 743.11,
#    'CH4': 6905.54,
#    'N2O': 5459.52,
#    'PFCs': 301.11,
#    'SF6': 119.6}},
#  {'country_id': 'SWE',
#   'year': 2003,
#   'emissions': {'CO2': 57203.6,
#    'HFCs': 790.72,
#    'CH4': 6697.66,
#    'N2O': 5526.47,
#    'PFCs': 297.78,
#    'SF6': 85.13}},
#  {'country_id': 'SWE',
#   'year': 2004,
#   'emissions': {'CO2': 56428.8,
#    'HFCs': 856.75,
#    'CH4': 6731.72,
#    'N2O': 5178.18,
#    'PFCs': 292.3,
#    'SF6': 94.69}},
#  {'country_id': 'SWE',
#   'year': 2005,
#   'emissions': {'CO2': 53859.21,
#    'HFCs': 880.32,
#    'CH4': 6559.36,
#    'N2O': 5222.35,
#    'PFCs': 295.47,
#    'SF6': 151.59}},
#  {'country_id': 'SWE',
#   'year': 2006,
#   'emissions': {'CO2': 53697.66,
#    'HFCs': 913.25,
#    'CH4': 6455.73,
#    'N2O': 5457.4,
#    'PFCs': 286.76,
#    'SF6': 112.64}},
#  {'country_id': 'SWE',
#   'year': 2007,
#   'emissions': {'CO2': 52911.73,
#    'HFCs': 937.99,
#    'CH4': 6198.32,
#    'N2O': 4893.0,
#    'PFCs': 294.24,
#    'SF6': 137.38}},
#  {'country_id': 'SWE',
#   'year': 2008,
#   'emissions': {'CO2': 50831.58,
#    'HFCs': 968.04,
#    'CH4': 5936.88,
#    'N2O': 5042.77,
#    'PFCs': 269.0,
#    'SF6': 72.85}},
#  {'country_id': 'SWE',
#   'year': 2009,
#   'emissions': {'CO2': 47267.45,
#    'HFCs': 973.2,
#    'CH4': 5805.54,
#    'N2O': 4890.34,
#    'PFCs': 46.23,
#    'SF6': 70.01}},
#  {'country_id': 'SWE',
#   'year': 2010,
#   'emissions': {'CO2': 53057.73,
#    'HFCs': 950.24,
#    'CH4': 5687.88,
#    'N2O': 5053.51,
#    'PFCs': 184.82,
#    'SF6': 62.91}},
#  {'country_id': 'SWE',
#   'year': 2011,
#   'emissions': {'CO2': 49133.59,
#    'HFCs': 915.23,
#    'CH4': 5564.03,
#    'N2O': 5106.58,
#    'PFCs': 212.95,
#    'SF6': 54.77}},
#  {'country_id': 'SWE',
#   'year': 2012,
#   'emissions': {'CO2': 46559.64,
#    'HFCs': 869.97,
#    'CH4': 5377.21,
#    'N2O': 4640.93,
#    'PFCs': 78.28,
#    'SF6': 52.34}},
#  {'country_id': 'SWE',
#   'year': 2013,
#   'emissions': {'CO2': 44899.15,
#    'HFCs': 838.55,
#    'CH4': 5277.93,
#    'N2O': 4831.68,
#    'PFCs': 51.0,
#    'SF6': 41.21}},
#  {'country_id': 'SWE',
#   'year': 2014,
#   'emissions': {'CO2': 43404.9,
#    'HFCs': 807.11,
#    'CH4': 5158.27,
#    'N2O': 4884.13,
#    'PFCs': 81.7,
#    'SF6': 46.62}},
#  {'country_id': 'TUR',
#   'year': 1990,
#   'emissions': {'CO2': 146750.64,
#    'CH4': 43820.36,
#    'N2O': 16509.56,
#    'PFCs': 692.77}},
#  {'country_id': 'TUR',
#   'year': 1991,
#   'emissions': {'CO2': 152335.17,
#    'CH4': 44842.01,
#    'N2O': 16096.6,
#    'PFCs': 854.54}},
#  {'country_id': 'TUR',
#   'year': 1992,
#   'emissions': {'CO2': 158571.55,
#    'CH4': 44659.26,
#    'N2O': 16784.42,
#    'PFCs': 781.92}},
#  {'country_id': 'TUR',
#   'year': 1993,
#   'emissions': {'CO2': 167443.15,
#    'CH4': 44556.55,
#    'N2O': 17842.71,
#    'PFCs': 786.58}},
#  {'country_id': 'TUR',
#   'year': 1994,
#   'emissions': {'CO2': 164623.55,
#    'CH4': 44126.26,
#    'N2O': 15275.77,
#    'PFCs': 693.65}},
#  {'country_id': 'TUR',
#   'year': 1995,
#   'emissions': {'CO2': 178812.41,
#    'CH4': 43881.32,
#    'N2O': 15753.18,
#    'PFCs': 592.88}},
#  {'country_id': 'TUR',
#   'year': 1996,
#   'emissions': {'CO2': 194751.78,
#    'CH4': 44230.78,
#    'N2O': 16720.6,
#    'PFCs': 597.28,
#    'SF6': 356.64}},
#  {'country_id': 'TUR',
#   'year': 1997,
#   'emissions': {'CO2': 208480.07,
#    'CH4': 43353.85,
#    'N2O': 16932.29,
#    'PFCs': 593.33,
#    'SF6': 582.97}},
#  {'country_id': 'TUR',
#   'year': 1998,
#   'emissions': {'CO2': 208365.34,
#    'CH4': 43468.35,
#    'N2O': 18699.09,
#    'PFCs': 593.87,
#    'SF6': 629.28}},
#  {'country_id': 'TUR',
#   'year': 1999,
#   'emissions': {'CO2': 206388.62,
#    'CH4': 44984.17,
#    'N2O': 18901.07,
#    'PFCs': 591.07,
#    'SF6': 493.03}},
#  {'country_id': 'TUR',
#   'year': 2000,
#   'emissions': {'CO2': 232549.19,
#    'HFCs': 115.66,
#    'CH4': 44821.5,
#    'N2O': 18425.08,
#    'PFCs': 591.38,
#    'SF6': 308.03}},
#  {'country_id': 'TUR',
#   'year': 2001,
#   'emissions': {'CO2': 217469.5,
#    'HFCs': 232.0,
#    'CH4': 44029.5,
#    'N2O': 16167.48,
#    'PFCs': 592.2,
#    'SF6': 294.26}},
#  {'country_id': 'TUR',
#   'year': 2002,
#   'emissions': {'CO2': 226365.41,
#    'HFCs': 417.19,
#    'CH4': 42186.58,
#    'N2O': 17074.65,
#    'PFCs': 595.92,
#    'SF6': 454.81}},
#  {'country_id': 'TUR',
#   'year': 2003,
#   'emissions': {'CO2': 240902.46,
#    'HFCs': 628.8,
#    'CH4': 43383.36,
#    'N2O': 17727.11,
#    'PFCs': 595.33,
#    'SF6': 457.37}},
#  {'country_id': 'TUR',
#   'year': 2004,
#   'emissions': {'CO2': 253172.08,
#    'HFCs': 909.37,
#    'CH4': 42957.66,
#    'N2O': 18581.67,
#    'PFCs': 600.78,
#    'SF6': 672.14}},
#  {'country_id': 'TUR',
#   'year': 2005,
#   'emissions': {'CO2': 279130.74,
#    'HFCs': 1146.88,
#    'CH4': 44591.04,
#    'N2O': 18983.96,
#    'PFCs': 559.97,
#    'SF6': 819.2}},
#  {'country_id': 'TUR',
#   'year': 2006,
#   'emissions': {'CO2': 302195.95,
#    'HFCs': 1424.19,
#    'CH4': 46145.68,
#    'N2O': 20235.5,
#    'PFCs': 450.06,
#    'SF6': 869.18}},
#  {'country_id': 'TUR',
#   'year': 2007,
#   'emissions': {'CO2': 333166.42,
#    'HFCs': 1713.19,
#    'CH4': 48509.6,
#    'N2O': 19094.98,
#    'SF6': 908.29}},
#  {'country_id': 'TUR',
#   'year': 2008,
#   'emissions': {'CO2': 323536.55,
#    'HFCs': 1896.14,
#    'CH4': 49560.39,
#    'N2O': 17303.54,
#    'SF6': 804.29}},
#  {'country_id': 'TUR',
#   'year': 2009,
#   'emissions': {'CO2': 310580.7,
#    'HFCs': 2111.28,
#    'CH4': 49378.73,
#    'N2O': 19676.22,
#    'SF6': 766.49}},
#  {'country_id': 'TUR',
#   'year': 2010,
#   'emissions': {'CO2': 320356.66,
#    'HFCs': 3054.34,
#    'CH4': 51415.14,
#    'N2O': 19620.89,
#    'SF6': 835.48}},
#  {'country_id': 'TUR',
#   'year': 2011,
#   'emissions': {'CO2': 338094.41,
#    'HFCs': 3432.69,
#    'CH4': 53909.35,
#    'N2O': 19525.88,
#    'SF6': 906.49}},
#  {'country_id': 'TUR',
#   'year': 2012,
#   'emissions': {'CO2': 363126.01,
#    'HFCs': 4256.86,
#    'CH4': 58027.01,
#    'N2O': 21116.02,
#    'SF6': 926.43}},
#  {'country_id': 'TUR',
#   'year': 2013,
#   'emissions': {'CO2': 354961.04,
#    'HFCs': 4470.25,
#    'CH4': 56177.47,
#    'N2O': 23210.82}},
#  {'country_id': 'TUR',
#   'year': 2014,
#   'emissions': {'CO2': 382213.4,
#    'HFCs': 4916.55,
#    'CH4': 57137.71,
#    'N2O': 23282.71}},
#  {'country_id': 'UKR',
#   'year': 1990,
#   'emissions': {'CO2': 693024.77,
#    'CH4': 189322.96,
#    'N2O': 55370.65,
#    'PFCs': 235.82,
#    'SF6': 0.01}},
#  ...]

# %% [markdown]
# We have the data in required format now, let's finish off by writing it to JSON files.

# %%
json.dump(countris, open("data/countries.json", "w"), indent=2)
json.dump(emissions, open("data/emissions.json", "w"), indent=2)

# %% [markdown]
# This marks the end of our data cleaning journey. We shall define Models, Views and Controllers in the NodeJS code. After that, we shall also write a simple frontend to explore the data.
